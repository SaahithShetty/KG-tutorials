# %% [markdown]
# Import libraries

# %%
# you need to install pykeen beforehand, see https://pykeen.readthedocs.io/en/stable/installation.html 
import numpy as np
import pandas as pd
import pykeen
import seaborn

# %% [markdown]
# # 1. Dataset exploration

# %% [markdown]
# PyKeen comes with its own datasets that can be used directly in a pipeline.
# Below we import it so that we can explore it later.

# %%
from pykeen.datasets import Nations

# %% [markdown]
# However, we want to be able tfo work with our own datasets as well, so we etch the online GoT dataset as well.

# %%
import requests
from pykeen import triples

url = 'https://ampligraph.s3-eu-west-1.amazonaws.com/datasets/GoT.csv'
open('GoT.csv', 'wb').write(requests.get(url).content)

# Format that can be read by a pd.from_csv should also be able to be read here, but the delimiter needs to be adjusted
# PyKEEN uses tabs as defaults
got = triples.TriplesFactory.from_path('GoT.csv',load_triples_kwargs=dict(delimiter=','))
got_triples = got.triples
got_triples[:5,]
# Out:
# Reconstructing all label-based triples. This is expensive and rarely needed.
# array([['Abelar Hightower', 'ALLIED_WITH',
#         'House Hightower of the Hightower'],
#        ['Acorn Hall', 'SEAT_OF', 'House Smallwood of Acorn Hall'],
#        ['Addam Frey', 'ALLIED_WITH', 'House Frey of the Crossing'],
#        ['Addam Marbrand', 'ALLIED_WITH', 'House Marbrand of Ashemark'],
#        ['Addam Osgrey', 'ALLIED_WITH', 'House Osgrey of Standfast']],
#       dtype='<U44')

# %% [markdown]
# ### Exercise 1
#
# List the unique subject and object entities found in the dataset. Then list all of the relationships that link the entities (note that some entities are not linked). Create an RDF version of the dataset, using your own namespaces, and save is as a ttl file.
#
# Using SPARQL, answer the following questions :
# 1. How many instances per class? Use ORDER BY to show the most popular class
# 2. What is the most common relation per each class?

# %%
### your code here
from rdflib import Graph, ConjunctiveGraph, Literal, BNode, Namespace, RDF, URIRef, RDFS
#Unique subjects, predicates, objects\n",
subj = np.unique([got_triples[i][0]for i in range(len(got_triples))])
pred = np.unique([got_triples[i][1]for i in range(len(got_triples))])
obj = np.unique([got_triples[i][2]for i in range(len(got_triples))])




subj = [got_triples[i][0]for i in range(len(got_triples))]

pred = [got_triples[i][1]for i in range(len(got_triples))]
obj =[got_triples[i][2]for i in range(len(got_triples))]

urisub = [URIRef(f"http://example.org/{i.replace(' ', '_')}") for i in subj]
uripred = [URIRef(f"http://example.org/{i.replace(' ', '_')}") for i in pred]
uriobj = [URIRef(f"http://example.org/{i.replace(' ', '_')}") for i in obj]
#create RDF version of dataset\n",
g = Graph()

#example namespace\n",
EX = Namespace("https://example.org/")
for s,p,o in zip(urisub,uripred,uriobj):
    g.add( (s, p, o) )
    v = g.serialize(destination="GOT.ttl")

# %%
d = Graph()
d.parse('GOT.ttl')
#print(d.serialize(format='ttl'))

#query how many instances per class

def Query1(graph):
   res = graph.query("""
    select ?subj (count(?subj) AS ?count) where { 
    # ?subj ?pred ?obj
        } group by ?subj order by desc(?count)
   """, initNs={'ns1': 'http://example.org/' })

   return list(res)

Query1(d)

# %%
 #query relations,


def Query1(graph):
    res = graph.query("""
    select distinct ?pred (count(?pred) AS ?count) where { 
    # ?s ?pred ?obj
    } group by ?pred order by desc(?count)
      """, initNs={'ns1': 'http://example.org/' })
    return list(res)  

Query1(d)
# Out:
# [(rdflib.term.URIRef('http://example.org/ALLIED_WITH'),
#   rdflib.term.Literal('1065', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/IN_REGION'),
#   rdflib.term.Literal('437', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/SWORN_TO'),
#   rdflib.term.Literal('397', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/LED_BY'),
#   rdflib.term.Literal('179', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/SEAT_OF'),
#   rdflib.term.Literal('151', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/SPOUSE'),
#   rdflib.term.Literal('109', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/PARENT_OF'),
#   rdflib.term.Literal('44', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/FOUNDED_BY'),
#   rdflib.term.Literal('43', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/BRANCH_OF'),
#   rdflib.term.Literal('42', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://example.org/HEIR_TO'),
#   rdflib.term.Literal('38', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))]

# %% [markdown]
# # 2. Defining train and test datasets

# %% [markdown]
# As is typical in machine learning, we need to split our dataset into training and test (and sometimes validation) datasets.
#
# What differs from the standard method of randomly sampling N points to make up our test set, is that our data points are two entities linked by some relationship, and we need to take care to ensure that all entities are represented in train and test sets by at least one triple.
#
# To accomplish this, PyKEEN provides the <b>pykeen.triples.TriplesFactory.split()</b> function, which defaults to an 80/20 split. It is also by default stratified, to ensure that the distribution of the test set corresponds to that of the training set. If you want to use early stopping, you will also need a validation set. The function takes a list of percentages as argument: if you want a 95/5 split you give it <b>[0.95,0.05]</b> as argument, if you want 90/5/5 (which would include a validation set as well) you give it <b>[0.9,0.05,0.05]</b> as argument and it will return 3 datasets.
#
# For sake of example, we will create a small test size that includes only 5% of triples.

# %%
# got_training, got_testing = got.split()
got_training, got_testing = got.split([0.95,0.05])

print('Train set size: ', got_training.triples.shape)
print('Test set size: ', got_testing.triples.shape)
# Out:
# using automatically assigned random_state=3039377849
# Reconstructing all label-based triples. This is expensive and rarely needed.
# Reconstructing all label-based triples. This is expensive and rarely needed.
# Train set size:  (3016, 3)
# Test set size:  (159, 3)

# %%
got_training
# Out:
# TriplesFactory(num_entities=2050, num_relations=10, create_inverse_triples=False, num_triples=3016, path="/Users/macoftraopia/Documents/GitHub/KRW-tutorials/solutions/GoT.csv")

# %% [markdown]
# ### Exercise 2
#
# Create three train-test sets of different sizes from the GoT data. Give them different names. Make sure the test set is not too big when compared to the training set (test set should be max 15% of the total dataset).

# %%
got_training_70, got_testing_70 = got.split([0.7,0.3])

got_training_80, got_testing_80 = got.split([0.8,0.2])

got_training_90, got_testing_90 = got.split([0.9,0.1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 got_training_70, got_testing_70 = got.split([0.7,0.3])
#       3 got_training_80, got_testing_80 = got.split([0.8,0.2])
#       5 got_training_90, got_testing_90 = got.split([0.9,0.1])
#
# NameError: name 'got' is not defined

# %% [markdown]
# # 3. Training and testing the model

# %% [markdown]
# PyKEEN has implemented several Knoweldge Graph Embedding models (TransE, ComplEx, DistMult, HolE, etc.). We will use the ComplEx model with default values for this tutorial.
#
# You can find the list of all implemented models in the documentation: https://pykeen.readthedocs.io/en/stable/reference/models.html

# %% [markdown]
# Importing a model and instantiate it:
# There are two ways to import and use a model, both are shown below and don't give different results but not importing the model before hand might cause the automatic importing to be slower, especially if you plan to use the same model multiple times.

# %%
# wee need the pipeline to run a model, so it is simpler to import it directly.
# Pykeen lets you train a model with the minimal amount of custom parameters

from pykeen.pipeline import pipeline

# here we don't import the model, but let PyKEEN do the importing.
pipeline_result_simple = pipeline(
    random_seed=0,
    model='ComplEx',
    training=got_training,
    testing=got_testing,
)
pipeline_result_simple.plot_losses()
# Out:
# No cuda devices were available. The model runs on CPU
# Training epochs on cpu: 100%|██████████| 5/5 [00:01<00:00,  2.75epoch/s, loss=14.7, prev_loss=15.2]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|██████████| 159/159 [00:00<00:00, 700triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.25s seconds
# <AxesSubplot: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %%
# here we import the model and use it directly.
from pykeen.models import ComplEx

pipeline_result_imported = pipeline(
    random_seed=0,
    model=ComplEx,
    training=got_training,
    testing=got_testing,
)
pipeline_result_imported.plot_losses()
# Out:
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# Training epochs on cpu: 100%|██████████| 5/5 [00:01<00:00,  2.65epoch/s, loss=14.7, prev_loss=15.2]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|██████████| 159/159 [00:00<00:00, 676triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.25s seconds
# <AxesSubplot: title={'center': 'Losses Plot'}, xlabel='Epoch', ylabel='marginranking Loss'>

# %% [markdown]
# You can retrieve different metrics from the results. Here we retrieve the mean reciprocal rank (MRR). The result is the same for both the simple and imported model, because we used the same random seed (0).

# %%
print(pipeline_result_imported.get_metric('mrr'))
print(pipeline_result_simple.get_metric('mrr'))
# Out:
# 0.0029294279011540443
# 0.0029294279011540443

# %%
# but to get a better performing model, you want to set different things
pipeline_result = pipeline(
    random_seed=0,
    model='ComplEx',
    training=got_training,
    testing=got_testing,
    epochs=200,
    dimensions=150,
    optimizer='adam',
    optimizer_kwargs={'lr':1e-3},
    loss='pairwisehinge', 
    regularizer='LP', 
    regularizer_kwargs={'p':3, 'weight':1e-5}, 
)
print(pipeline_result.get_metric('mrr'))
# Out:
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# Training epochs on cpu: 100%|██████████| 200/200 [01:11<00:00,  2.80epoch/s, loss=0.299, prev_loss=0.306]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|██████████| 159/159 [00:00<00:00, 525triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.33s seconds
# 0.0023405710235238075

# %% [markdown]
# Understanding the parameters:
#
# - dimensions : the dimensionality of the embedding space
# - negative_sampler : the negative samplic strategy, here set to default (not used in arguments).
# - batch_size : the number of batches in which the training set is split during the training loop. If you are having into low memory issues than settings this to a higher number may help.
# - epochs : the number of epochs to train the model for.
# - optimizer : the Adam optimizer, with a learning rate of $1e-3$ set via the <i>optimizer_kwarg</i>.
# - loss : pairwise loss, with a margin of $0.5$ set via the <i>loss_kwarg</i>.
# - regularizer :  regularization with $p=2$, i.e. $l_2$ regularization. $\lambda$ = $1e-5$, set via the <i>regularizer_kwarg</i>.

# %% [markdown]
# ### Filtering Negatives
#
# To ensure our model can be trained and evaluated correctly, we need to define a filter to ensure that no negative statements generated by the corruption procedure are actually positives. This is simply done by concatenating train and test sets. When negative triples are generated by the corruption strategy, we can check that they aren't actually true statements.
#
# With PyKEEN this is made very easy, and can simply be passed as an argument.

# %%
pipeline_result = pipeline(
    model='ComplEx',
    training=got_training,
    testing=got_testing,
    epochs=200,
    dimensions=150,
    optimizer='adam',
    optimizer_kwargs={'lr':1e-3},
    loss='pairwisehinge', 
    regularizer='LP', 
    regularizer_kwargs={'p':3, 'weight':1e-5}, 
    
    negative_sampler='basic',
    negative_sampler_kwargs=dict(
        filtered=True,
    )
)
print(pipeline_result.get_metric('mrr'))
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 522401844.
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# Training epochs on cpu:   0%|                                                         | 0/200 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.71batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.71batch/s]
# Training epochs on cpu:   0%|▏                        | 1/200 [00:00<01:03,  3.15epoch/s, loss=16, prev_loss=nan]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.34batch/s]
# Training epochs on cpu:   1%|▎                         | 2/200 [00:00<00:59,  3.30epoch/s, loss=16, prev_loss=16]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.41batch/s]
# Training epochs on cpu:   2%|▎                       | 3/200 [00:00<00:56,  3.46epoch/s, loss=14.8, prev_loss=16]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.07batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.95batch/s]
# Training epochs on cpu:   2%|▍                     | 4/200 [00:01<00:59,  3.29epoch/s, loss=14.9, prev_loss=14.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 51.02batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 50.88batch/s]
# Training epochs on cpu:   2%|▌                     | 5/200 [00:01<01:01,  3.19epoch/s, loss=13.7, prev_loss=14.9]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.33batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.21batch/s]
# Training epochs on cpu:   3%|▋                       | 6/200 [00:01<01:01,  3.16epoch/s, loss=14, prev_loss=13.7]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 47.59batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 51.31batch/s]
# Training epochs on cpu:   4%|▊                       | 7/200 [00:02<01:01,  3.14epoch/s, loss=12.8, prev_loss=14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 48.59batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 50.76batch/s]
# Training epochs on cpu:   4%|▉                     | 8/200 [00:02<01:01,  3.11epoch/s, loss=12.5, prev_loss=12.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.11batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.52batch/s]
# Training epochs on cpu:   4%|▉                     | 9/200 [00:02<01:01,  3.08epoch/s, loss=12.3, prev_loss=12.5]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 49.94batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 49.43batch/s]
# Training epochs on cpu:   5%|█                    | 10/200 [00:03<01:02,  3.02epoch/s, loss=11.8, prev_loss=12.3]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.19batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 50.48batch/s]
# Training epochs on cpu:   6%|█▏                   | 11/200 [00:03<01:02,  3.04epoch/s, loss=11.3, prev_loss=11.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 47.77batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 47.73batch/s]
# Training epochs on cpu:   6%|█▎                   | 12/200 [00:03<01:02,  3.00epoch/s, loss=10.6, prev_loss=11.3]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 49.24batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 51.16batch/s]
# Training epochs on cpu:   6%|█▎                   | 13/200 [00:04<01:01,  3.02epoch/s, loss=10.4, prev_loss=10.6]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 50.19batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 50.00batch/s]
# Training epochs on cpu:   7%|█▍                   | 14/200 [00:04<01:01,  3.01epoch/s, loss=10.5, prev_loss=10.4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 50.19batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 50.18batch/s]
# Training epochs on cpu:   8%|█▌                   | 15/200 [00:04<01:02,  2.98epoch/s, loss=9.71, prev_loss=10.5]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 51.18batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.13batch/s]
# Training epochs on cpu:   8%|█▋                   | 16/200 [00:05<01:01,  3.00epoch/s, loss=9.76, prev_loss=9.71]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.60batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.24batch/s]
# Training epochs on cpu:   8%|█▊                   | 17/200 [00:05<00:59,  3.09epoch/s, loss=9.18, prev_loss=9.76]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.01batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.53batch/s]
# Training epochs on cpu:   9%|█▉                   | 18/200 [00:05<00:57,  3.14epoch/s, loss=8.99, prev_loss=9.18]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.29batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.19batch/s]
# Training epochs on cpu:  10%|█▉                   | 19/200 [00:06<00:57,  3.17epoch/s, loss=8.69, prev_loss=8.99]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.71batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.85batch/s]
# Training epochs on cpu:  10%|██                   | 20/200 [00:06<00:56,  3.20epoch/s, loss=8.35, prev_loss=8.69]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.13batch/s]
# Training epochs on cpu:  10%|██▏                  | 21/200 [00:06<00:54,  3.26epoch/s, loss=8.07, prev_loss=8.35]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.68batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.22batch/s]
# Training epochs on cpu:  11%|██▎                  | 22/200 [00:07<00:53,  3.30epoch/s, loss=7.79, prev_loss=8.07]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.38batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.09batch/s]
# Training epochs on cpu:  12%|██▍                  | 23/200 [00:07<00:54,  3.27epoch/s, loss=7.87, prev_loss=7.79]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.47batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.29batch/s]
# Training epochs on cpu:  12%|██▋                   | 24/200 [00:07<00:53,  3.28epoch/s, loss=7.3, prev_loss=7.87]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.55batch/s]
# Training epochs on cpu:  12%|██▊                   | 25/200 [00:07<00:52,  3.33epoch/s, loss=7.31, prev_loss=7.3]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.09batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.37batch/s]
# Training epochs on cpu:  13%|██▋                  | 26/200 [00:08<00:52,  3.33epoch/s, loss=7.11, prev_loss=7.31]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.65batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.26batch/s]
# Training epochs on cpu:  14%|██▊                  | 27/200 [00:08<00:52,  3.32epoch/s, loss=6.78, prev_loss=7.11]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.09batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.28batch/s]
# Training epochs on cpu:  14%|██▉                  | 28/200 [00:08<00:50,  3.38epoch/s, loss=6.33, prev_loss=6.78]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.89batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.86batch/s]
# Training epochs on cpu:  14%|███▏                  | 29/200 [00:09<00:51,  3.35epoch/s, loss=6.2, prev_loss=6.33]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.72batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.52batch/s]
# Training epochs on cpu:  15%|███▎                  | 30/200 [00:09<00:50,  3.34epoch/s, loss=6.29, prev_loss=6.2]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.55batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 59.39batch/s]
# Training epochs on cpu:  16%|███▍                  | 31/200 [00:09<00:50,  3.35epoch/s, loss=5.5, prev_loss=6.29]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.68batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.12batch/s]
# Training epochs on cpu:  16%|███▌                  | 32/200 [00:09<00:50,  3.33epoch/s, loss=5.17, prev_loss=5.5]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.32batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.49batch/s]
# Training epochs on cpu:  16%|███▍                 | 33/200 [00:10<00:50,  3.31epoch/s, loss=5.23, prev_loss=5.17]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.03batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.84batch/s]
# Training epochs on cpu:  17%|███▋                  | 34/200 [00:10<00:49,  3.37epoch/s, loss=5.7, prev_loss=5.23]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.54batch/s]
# Training epochs on cpu:  18%|███▊                  | 35/200 [00:10<00:47,  3.44epoch/s, loss=5.26, prev_loss=5.7]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.57batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.59batch/s]
# Training epochs on cpu:  18%|███▊                 | 36/200 [00:11<00:48,  3.37epoch/s, loss=4.91, prev_loss=5.26]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.70batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.62batch/s]
# Training epochs on cpu:  18%|███▉                 | 37/200 [00:11<00:48,  3.34epoch/s, loss=4.77, prev_loss=4.91]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.33batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.64batch/s]
# Training epochs on cpu:  19%|███▉                 | 38/200 [00:11<00:48,  3.32epoch/s, loss=4.99, prev_loss=4.77]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.74batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.48batch/s]
# Training epochs on cpu:  20%|████                 | 39/200 [00:12<00:47,  3.38epoch/s, loss=4.43, prev_loss=4.99]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.98batch/s]
# Training epochs on cpu:  20%|████▏                | 40/200 [00:12<00:47,  3.39epoch/s, loss=4.14, prev_loss=4.43]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.92batch/s]
# Training epochs on cpu:  20%|████▎                | 41/200 [00:12<00:46,  3.41epoch/s, loss=4.16, prev_loss=4.14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.69batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.19batch/s]
# Training epochs on cpu:  21%|████▍                | 42/200 [00:12<00:46,  3.38epoch/s, loss=4.21, prev_loss=4.16]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.50batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.27batch/s]
# Training epochs on cpu:  22%|████▌                | 43/200 [00:13<00:47,  3.32epoch/s, loss=4.02, prev_loss=4.21]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.80batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.13batch/s]
# Training epochs on cpu:  22%|████▌                | 44/200 [00:13<00:46,  3.33epoch/s, loss=4.12, prev_loss=4.02]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.10batch/s]
# Training epochs on cpu:  22%|████▋                | 45/200 [00:13<00:45,  3.40epoch/s, loss=3.83, prev_loss=4.12]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.90batch/s]
# Training epochs on cpu:  23%|█████                 | 46/200 [00:14<00:45,  3.41epoch/s, loss=3.6, prev_loss=3.83]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.15batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.72batch/s]
# Training epochs on cpu:  24%|█████▏                | 47/200 [00:14<00:45,  3.38epoch/s, loss=3.54, prev_loss=3.6]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.18batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.00batch/s]
# Training epochs on cpu:  24%|█████                | 48/200 [00:14<00:45,  3.36epoch/s, loss=3.32, prev_loss=3.54]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.69batch/s]
# Training epochs on cpu:  24%|█████▏               | 49/200 [00:15<00:43,  3.44epoch/s, loss=3.46, prev_loss=3.32]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.19batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.97batch/s]
# Training epochs on cpu:  25%|█████▎               | 50/200 [00:15<00:44,  3.39epoch/s, loss=3.58, prev_loss=3.46]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.36batch/s]
# Training epochs on cpu:  26%|█████▎               | 51/200 [00:15<00:43,  3.44epoch/s, loss=3.41, prev_loss=3.58]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.56batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.76batch/s]
# Training epochs on cpu:  26%|█████▍               | 52/200 [00:15<00:42,  3.46epoch/s, loss=3.02, prev_loss=3.41]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.05batch/s]
# Training epochs on cpu:  26%|█████▌               | 53/200 [00:16<00:41,  3.55epoch/s, loss=3.25, prev_loss=3.02]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.26batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.54batch/s]
# Training epochs on cpu:  27%|█████▋               | 54/200 [00:16<00:42,  3.44epoch/s, loss=3.21, prev_loss=3.25]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.87batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.41batch/s]
# Training epochs on cpu:  28%|█████▊               | 55/200 [00:16<00:42,  3.39epoch/s, loss=2.58, prev_loss=3.21]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.67batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.57batch/s]
# Training epochs on cpu:  28%|█████▉               | 56/200 [00:17<00:42,  3.36epoch/s, loss=2.72, prev_loss=2.58]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.06batch/s]
# Training epochs on cpu:  28%|█████▉               | 57/200 [00:17<00:41,  3.41epoch/s, loss=2.91, prev_loss=2.72]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.78batch/s]
# Training epochs on cpu:  29%|██████▍               | 58/200 [00:17<00:40,  3.48epoch/s, loss=2.9, prev_loss=2.91]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.34batch/s]
# Training epochs on cpu:  30%|██████▍               | 59/200 [00:17<00:40,  3.52epoch/s, loss=2.56, prev_loss=2.9]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.32batch/s]
# Training epochs on cpu:  30%|██████▌               | 60/200 [00:18<00:40,  3.49epoch/s, loss=2.8, prev_loss=2.56]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.03batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.42batch/s]
# Training epochs on cpu:  30%|██████▋               | 61/200 [00:18<00:40,  3.43epoch/s, loss=2.44, prev_loss=2.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.75batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.70batch/s]
# Training epochs on cpu:  31%|██████▌              | 62/200 [00:18<00:40,  3.40epoch/s, loss=2.54, prev_loss=2.44]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.28batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.53batch/s]
# Training epochs on cpu:  32%|██████▌              | 63/200 [00:19<00:39,  3.44epoch/s, loss=2.43, prev_loss=2.54]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.81batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.56batch/s]
# Training epochs on cpu:  32%|██████▋              | 64/200 [00:19<00:39,  3.41epoch/s, loss=2.26, prev_loss=2.43]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.79batch/s]
# Training epochs on cpu:  32%|██████▊              | 65/200 [00:19<00:38,  3.47epoch/s, loss=2.11, prev_loss=2.26]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.70batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.68batch/s]
# Training epochs on cpu:  33%|██████▉              | 66/200 [00:19<00:39,  3.41epoch/s, loss=2.14, prev_loss=2.11]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.22batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.25batch/s]
# Training epochs on cpu:  34%|███████              | 67/200 [00:20<00:39,  3.38epoch/s, loss=2.23, prev_loss=2.14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.49batch/s]
# Training epochs on cpu:  34%|███████▏             | 68/200 [00:20<00:38,  3.43epoch/s, loss=2.09, prev_loss=2.23]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.68batch/s]
# Training epochs on cpu:  34%|███████▏             | 69/200 [00:20<00:38,  3.42epoch/s, loss=1.96, prev_loss=2.09]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.22batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.21batch/s]
# Training epochs on cpu:  35%|███████▎             | 70/200 [00:21<00:38,  3.38epoch/s, loss=2.03, prev_loss=1.96]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.20batch/s]
# Training epochs on cpu:  36%|███████▍             | 71/200 [00:21<00:37,  3.46epoch/s, loss=1.93, prev_loss=2.03]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.04batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 59.13batch/s]
# Training epochs on cpu:  36%|███████▌             | 72/200 [00:21<00:37,  3.43epoch/s, loss=1.79, prev_loss=1.93]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.13batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.61batch/s]
# Training epochs on cpu:  36%|███████▋             | 73/200 [00:22<00:37,  3.39epoch/s, loss=1.67, prev_loss=1.79]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.76batch/s]
# Training epochs on cpu:  37%|███████▊             | 74/200 [00:22<00:36,  3.43epoch/s, loss=1.93, prev_loss=1.67]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.49batch/s]
# Training epochs on cpu:  38%|███████▉             | 75/200 [00:22<00:35,  3.50epoch/s, loss=1.98, prev_loss=1.93]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.57batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.69batch/s]
# Training epochs on cpu:  38%|████████▎             | 76/200 [00:22<00:35,  3.51epoch/s, loss=1.6, prev_loss=1.98]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.30batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.88batch/s]
# Training epochs on cpu:  38%|████████▍             | 77/200 [00:23<00:35,  3.45epoch/s, loss=1.73, prev_loss=1.6]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.24batch/s]
# Training epochs on cpu:  39%|████████▌             | 78/200 [00:23<00:35,  3.42epoch/s, loss=1.6, prev_loss=1.73]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.85batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.40batch/s]
# Training epochs on cpu:  40%|████████▋             | 79/200 [00:23<00:35,  3.38epoch/s, loss=1.59, prev_loss=1.6]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.06batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.75batch/s]
# Training epochs on cpu:  40%|████████▍            | 80/200 [00:24<00:35,  3.41epoch/s, loss=1.58, prev_loss=1.59]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.59batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 50.90batch/s]
# Training epochs on cpu:  40%|████████▌            | 81/200 [00:24<00:35,  3.32epoch/s, loss=1.51, prev_loss=1.58]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.47batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.58batch/s]
# Training epochs on cpu:  41%|████████▌            | 82/200 [00:24<00:35,  3.28epoch/s, loss=1.67, prev_loss=1.51]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.00batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.41batch/s]
# Training epochs on cpu:  42%|████████▋            | 83/200 [00:25<00:36,  3.23epoch/s, loss=1.45, prev_loss=1.67]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.58batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.97batch/s]
# Training epochs on cpu:  42%|████████▊            | 84/200 [00:25<00:36,  3.21epoch/s, loss=1.23, prev_loss=1.45]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 44.67batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 47.41batch/s]
# Training epochs on cpu:  42%|████████▉            | 85/200 [00:25<00:37,  3.09epoch/s, loss=1.47, prev_loss=1.23]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 51.65batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.27batch/s]
# Training epochs on cpu:  43%|█████████▍            | 86/200 [00:25<00:36,  3.10epoch/s, loss=1.5, prev_loss=1.47]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 44.98batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 48.68batch/s]
# Training epochs on cpu:  44%|█████████▌            | 87/200 [00:26<00:37,  2.98epoch/s, loss=1.24, prev_loss=1.5]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.52batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.33batch/s]
# Training epochs on cpu:  44%|█████████▏           | 88/200 [00:26<00:37,  2.99epoch/s, loss=1.53, prev_loss=1.24]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.31batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.52batch/s]
# Training epochs on cpu:  44%|█████████▎           | 89/200 [00:27<00:36,  3.01epoch/s, loss=1.28, prev_loss=1.53]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.57batch/s]
# Training epochs on cpu:  45%|█████████▍           | 90/200 [00:27<00:35,  3.14epoch/s, loss=1.19, prev_loss=1.28]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.60batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.42batch/s]
# Training epochs on cpu:  46%|█████████▌           | 91/200 [00:27<00:34,  3.20epoch/s, loss=1.36, prev_loss=1.19]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.53batch/s]
# Training epochs on cpu:  46%|█████████▋           | 92/200 [00:27<00:33,  3.27epoch/s, loss=1.27, prev_loss=1.36]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.16batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 59.39batch/s]
# Training epochs on cpu:  46%|██████████▏           | 93/200 [00:28<00:32,  3.31epoch/s, loss=1.3, prev_loss=1.27]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.62batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.62batch/s]
# Training epochs on cpu:  47%|██████████▎           | 94/200 [00:28<00:32,  3.28epoch/s, loss=1.36, prev_loss=1.3]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.75batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.63batch/s]
# Training epochs on cpu:  48%|█████████▉           | 95/200 [00:28<00:31,  3.30epoch/s, loss=1.08, prev_loss=1.36]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.39batch/s]
# Training epochs on cpu:  48%|██████████           | 96/200 [00:29<00:30,  3.45epoch/s, loss=1.19, prev_loss=1.08]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.07batch/s]
# Training epochs on cpu:  48%|██████████▋           | 97/200 [00:29<00:30,  3.42epoch/s, loss=1.2, prev_loss=1.19]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.20batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.03batch/s]
# Training epochs on cpu:  49%|██████████▊           | 98/200 [00:29<00:30,  3.34epoch/s, loss=1.27, prev_loss=1.2]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.43batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.79batch/s]
# Training epochs on cpu:  50%|██████████▍          | 99/200 [00:29<00:30,  3.32epoch/s, loss=1.01, prev_loss=1.27]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.84batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.28batch/s]
# Training epochs on cpu:  50%|██████████          | 100/200 [00:30<00:30,  3.31epoch/s, loss=1.24, prev_loss=1.01]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.03batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.97batch/s]
# Training epochs on cpu:  50%|██████████          | 101/200 [00:30<00:29,  3.32epoch/s, loss=1.15, prev_loss=1.24]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.20batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.19batch/s]
# Training epochs on cpu:  51%|█████████▋         | 102/200 [00:30<00:29,  3.31epoch/s, loss=0.956, prev_loss=1.15]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.97batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.86batch/s]
# Training epochs on cpu:  52%|█████████▊         | 103/200 [00:31<00:29,  3.27epoch/s, loss=1.19, prev_loss=0.956]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.17batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.20batch/s]
# Training epochs on cpu:  52%|█████████▉         | 104/200 [00:31<00:29,  3.24epoch/s, loss=0.953, prev_loss=1.19]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.23batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.99batch/s]
# Training epochs on cpu:  52%|█████████▍        | 105/200 [00:31<00:28,  3.31epoch/s, loss=0.829, prev_loss=0.953]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.10batch/s]
# Training epochs on cpu:  53%|██████████         | 106/200 [00:32<00:27,  3.40epoch/s, loss=1.11, prev_loss=0.829]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.95batch/s]
# Training epochs on cpu:  54%|██████████▏        | 107/200 [00:32<00:27,  3.40epoch/s, loss=0.829, prev_loss=1.11]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.66batch/s]
# Training epochs on cpu:  54%|██████████▎        | 108/200 [00:32<00:26,  3.45epoch/s, loss=1.03, prev_loss=0.829]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.46batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.91batch/s]
# Training epochs on cpu:  55%|██████████▉         | 109/200 [00:32<00:26,  3.38epoch/s, loss=1.06, prev_loss=1.03]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.96batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.05batch/s]
# Training epochs on cpu:  55%|██████████▍        | 110/200 [00:33<00:27,  3.31epoch/s, loss=0.912, prev_loss=1.06]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.10batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.31batch/s]
# Training epochs on cpu:  56%|██████████▌        | 111/200 [00:33<00:27,  3.28epoch/s, loss=0.97, prev_loss=0.912]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.52batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.05batch/s]
# Training epochs on cpu:  56%|██████████▋        | 112/200 [00:33<00:27,  3.25epoch/s, loss=0.949, prev_loss=0.97]
# ...
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 50.58batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.23batch/s]
# Training epochs on cpu:  83%|██████████████▉   | 166/200 [00:50<00:11,  3.00epoch/s, loss=0.383, prev_loss=0.313]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 50.36batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 50.57batch/s]
# Training epochs on cpu:  84%|███████████████   | 167/200 [00:51<00:11,  2.98epoch/s, loss=0.353, prev_loss=0.383]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 49.46batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 53.78batch/s]
# Training epochs on cpu:  84%|███████████████   | 168/200 [00:51<00:10,  3.02epoch/s, loss=0.401, prev_loss=0.353]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.31batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.87batch/s]
# Training epochs on cpu:  84%|███████████████▏  | 169/200 [00:51<00:10,  3.10epoch/s, loss=0.326, prev_loss=0.401]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.49batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.92batch/s]
# Training epochs on cpu:  85%|███████████████▎  | 170/200 [00:52<00:09,  3.11epoch/s, loss=0.337, prev_loss=0.326]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 50.38batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.10batch/s]
# Training epochs on cpu:  86%|████████████████▏  | 171/200 [00:52<00:09,  3.09epoch/s, loss=0.45, prev_loss=0.337]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 49.72batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 50.80batch/s]
# Training epochs on cpu:  86%|████████████████▎  | 172/200 [00:52<00:09,  3.06epoch/s, loss=0.417, prev_loss=0.45]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.55batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.27batch/s]
# Training epochs on cpu:  86%|████████████████▍  | 173/200 [00:53<00:08,  3.09epoch/s, loss=0.41, prev_loss=0.417]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.59batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.52batch/s]
# Training epochs on cpu:  87%|████████████████▌  | 174/200 [00:53<00:08,  3.09epoch/s, loss=0.373, prev_loss=0.41]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.48batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.92batch/s]
# Training epochs on cpu:  88%|███████████████▊  | 175/200 [00:53<00:08,  3.09epoch/s, loss=0.328, prev_loss=0.373]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.26batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.43batch/s]
# Training epochs on cpu:  88%|███████████████▊  | 176/200 [00:54<00:07,  3.13epoch/s, loss=0.273, prev_loss=0.328]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.09batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.36batch/s]
# Training epochs on cpu:  88%|███████████████▉  | 177/200 [00:54<00:07,  3.19epoch/s, loss=0.329, prev_loss=0.273]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.58batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.44batch/s]
# Training epochs on cpu:  89%|████████████████  | 178/200 [00:54<00:06,  3.18epoch/s, loss=0.374, prev_loss=0.329]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.52batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.54batch/s]
# Training epochs on cpu:  90%|████████████████  | 179/200 [00:55<00:06,  3.20epoch/s, loss=0.262, prev_loss=0.374]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.81batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.01batch/s]
# Training epochs on cpu:  90%|████████████████▏ | 180/200 [00:55<00:06,  3.18epoch/s, loss=0.339, prev_loss=0.262]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.66batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.21batch/s]
# Training epochs on cpu:  90%|████████████████▎ | 181/200 [00:55<00:05,  3.18epoch/s, loss=0.353, prev_loss=0.339]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.67batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.80batch/s]
# Training epochs on cpu:  91%|████████████████▍ | 182/200 [00:56<00:05,  3.17epoch/s, loss=0.352, prev_loss=0.353]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.49batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.71batch/s]
# Training epochs on cpu:  92%|████████████████▍ | 183/200 [00:56<00:05,  3.19epoch/s, loss=0.332, prev_loss=0.352]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 51.37batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 48.22batch/s]
# Training epochs on cpu:  92%|████████████████▌ | 184/200 [00:56<00:05,  3.14epoch/s, loss=0.363, prev_loss=0.332]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.26batch/s]
# Training epochs on cpu:  92%|████████████████▋ | 185/200 [00:56<00:04,  3.23epoch/s, loss=0.273, prev_loss=0.363]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.38batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.28batch/s]
# Training epochs on cpu:  93%|████████████████▋ | 186/200 [00:57<00:04,  3.23epoch/s, loss=0.264, prev_loss=0.273]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.41batch/s]
# Training epochs on cpu:  94%|████████████████▊ | 187/200 [00:57<00:03,  3.37epoch/s, loss=0.277, prev_loss=0.264]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.88batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.80batch/s]
# Training epochs on cpu:  94%|████████████████▉ | 188/200 [00:57<00:03,  3.34epoch/s, loss=0.306, prev_loss=0.277]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.08batch/s]
# Training epochs on cpu:  94%|█████████████████ | 189/200 [00:58<00:03,  3.42epoch/s, loss=0.338, prev_loss=0.306]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.94batch/s]
# Training epochs on cpu:  95%|█████████████████ | 190/200 [00:58<00:02,  3.49epoch/s, loss=0.332, prev_loss=0.338]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.70batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.94batch/s]
# Training epochs on cpu:  96%|██████████████████▏| 191/200 [00:58<00:02,  3.37epoch/s, loss=0.29, prev_loss=0.332]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.09batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.40batch/s]
# Training epochs on cpu:  96%|██████████████████▏| 192/200 [00:59<00:02,  3.29epoch/s, loss=0.292, prev_loss=0.29]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 50.62batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.22batch/s]
# Training epochs on cpu:  96%|█████████████████▎| 193/200 [00:59<00:02,  3.23epoch/s, loss=0.313, prev_loss=0.292]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.15batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.16batch/s]
# Training epochs on cpu:  97%|█████████████████▍| 194/200 [00:59<00:01,  3.21epoch/s, loss=0.328, prev_loss=0.313]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.93batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.28batch/s]
# Training epochs on cpu:  98%|█████████████████▌| 195/200 [01:00<00:01,  3.21epoch/s, loss=0.306, prev_loss=0.328]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.19batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.70batch/s]
# Training epochs on cpu:  98%|█████████████████▋| 196/200 [01:00<00:01,  3.21epoch/s, loss=0.254, prev_loss=0.306]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 51.24batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.92batch/s]
# Training epochs on cpu:  98%|█████████████████▋| 197/200 [01:00<00:00,  3.15epoch/s, loss=0.264, prev_loss=0.254]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 51.87batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.45batch/s]
# Training epochs on cpu:  99%|█████████████████▊| 198/200 [01:00<00:00,  3.13epoch/s, loss=0.376, prev_loss=0.264]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.66batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.20batch/s]
# Training epochs on cpu: 100%|█████████████████▉| 199/200 [01:01<00:00,  3.09epoch/s, loss=0.317, prev_loss=0.376]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.06batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 52.56batch/s]
# Training epochs on cpu: 100%|██████████████████| 200/200 [01:01<00:00,  3.24epoch/s, loss=0.266, prev_loss=0.317]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|███████████████████████████████████████████████████| 159/159 [00:00<00:00, 1.05ktriple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.16s seconds
# 0.0033772025468214507

# %% [markdown]
# To save your learned model and also the results, we need to add checkpoints to the pipeline.
# By adding training kwargs to the pipeline, the model will be automatically saved. By default, it saves the model after every epoch (checkpoint_frequency=0). You can also set the directory to which the models are saved, but by default they will end up in ~/.data/pykeen/checkpoints.

# %%
pipeline_result = pipeline(
    model='ComplEx',
    training=got_training,
    testing=got_testing,
    training_kwargs=dict(
        num_epochs=200,
        checkpoint_name='got_complex_checkpoint.pt',
        checkpoint_directory='checkpoint_dir/',
        checkpoint_frequency=20,
    ),
    dimensions=150,
    optimizer='adam',
    optimizer_kwargs={'lr':1e-3},
    loss='pairwisehinge', 
    regularizer='LP', 
    regularizer_kwargs={'p':3, 'weight':1e-5}, 
    negative_sampler='basic',
    negative_sampler_kwargs=dict(
        filtered=True,
    )
)
# Out:
# INFO:pykeen.pipeline.api:loaded random seed 242643974 from checkpoint.
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.training.training_loop:=> loading checkpoint 'checkpoint_dir/got_complex_checkpoint.pt'
# INFO:pykeen.training.training_loop:=> loaded checkpoint 'checkpoint_dir/got_complex_checkpoint.pt' stopped after having finished epoch 200
# INFO:pykeen.stoppers.stopper:=> loading stopper summary dict from training loop checkpoint in 'checkpoint_dir/got_complex_checkpoint.pt'
# INFO:pykeen.stoppers.stopper:=> loaded stopper summary dictionary from checkpoint in 'checkpoint_dir/got_complex_checkpoint.pt'
# WARNING:pykeen.training.training_loop:the training loop was configured with a stopper but no stopper configuration was saved in the checkpoint
# Training epochs on cpu: 100%|███████████████████████████████████████████████████████| 200/200 [00:00<?, ?epoch/s]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|███████████████████████████████████████████████████| 159/159 [00:00<00:00, 1.02ktriple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.17s seconds

# %% [markdown]
# There is another way to save models, but for that we need to do the training and evaluating outside of the pipeline model. Below is an example of the above model training outside of the pipeline module.

# %%
from pykeen.models import ComplEx
model = ComplEx(triples_factory=got_training)

from pykeen.optimizers import Adam
optimizer = Adam(params=model.get_grad_params())

# from pykeen.regularizers import LP
# regularizer = LP(p=3,weight=1e-5)

from pykeen.training import SLCWATrainingLoop
training_loop = SLCWATrainingLoop(model=model,
                                  triples_factory=got_training,
                                  optimizer=optimizer)

#training
_ = training_loop.train(triples_factory=got_training,
                    num_epochs=200)

#evaluating
from pykeen.evaluation import RankBasedEvaluator
evaluator = RankBasedEvaluator()
mapped_triples = got_testing.mapped_triples

results = evaluator.evaluate(
            model=model,
            mapped_triples=mapped_triples,
            )

print(results.get_metric('mrr'))

#save results, this works also with the pipeline results, as the results object 
#returned by the evaluator is the same as the one returned from the pipeline
#THIS DOES NOT WORK FOR SOME REASON...
results.save_to_directory('got_complex')

import torch
torch.save(model,'trained_model.pkl')

#to load the model use the following command
# my_pykeen_model = torch.load('trained_model.pkl')
# Out:
# WARNING:pykeen.models.base:No random seed is specified. This may lead to non-reproducible results.
# INFO:pykeen.training.training_loop:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value '{batch_size}'
# Training epochs on cpu:   0%|                                                         | 0/200 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.66batch/s]
# Training epochs on cpu:   0%|                       | 1/200 [00:00<00:55,  3.62epoch/s, loss=10.8, prev_loss=nan]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.13batch/s]
# Training epochs on cpu:   1%|▏                       | 2/200 [00:00<00:54,  3.66epoch/s, loss=11, prev_loss=10.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.29batch/s]
# Training epochs on cpu:   2%|▎                       | 3/200 [00:00<00:52,  3.75epoch/s, loss=10.6, prev_loss=11]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 83.94batch/s]
# Training epochs on cpu:   2%|▍                     | 4/200 [00:01<00:48,  4.01epoch/s, loss=9.95, prev_loss=10.6]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.48batch/s]
# Training epochs on cpu:   2%|▌                     | 5/200 [00:01<00:48,  4.00epoch/s, loss=9.88, prev_loss=9.95]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.21batch/s]
# Training epochs on cpu:   3%|▋                     | 6/200 [00:01<00:49,  3.96epoch/s, loss=9.66, prev_loss=9.88]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.71batch/s]
# Training epochs on cpu:   4%|▊                     | 7/200 [00:01<00:48,  3.96epoch/s, loss=9.11, prev_loss=9.66]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.38batch/s]
# Training epochs on cpu:   4%|▉                     | 8/200 [00:02<00:47,  4.07epoch/s, loss=8.88, prev_loss=9.11]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.00batch/s]
# Training epochs on cpu:   4%|▉                     | 9/200 [00:02<00:46,  4.12epoch/s, loss=8.54, prev_loss=8.88]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.74batch/s]
# Training epochs on cpu:   5%|█                     | 10/200 [00:02<00:45,  4.17epoch/s, loss=8.2, prev_loss=8.54]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.52batch/s]
# Training epochs on cpu:   6%|█▏                    | 11/200 [00:02<00:45,  4.11epoch/s, loss=8.21, prev_loss=8.2]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.18batch/s]
# Training epochs on cpu:   6%|█▎                    | 12/200 [00:02<00:45,  4.16epoch/s, loss=7.8, prev_loss=8.21]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 84.96batch/s]
# Training epochs on cpu:   6%|█▍                    | 13/200 [00:03<00:44,  4.17epoch/s, loss=7.75, prev_loss=7.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 87.03batch/s]
# Training epochs on cpu:   7%|█▍                   | 14/200 [00:03<00:44,  4.18epoch/s, loss=7.52, prev_loss=7.75]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 81.16batch/s]
# Training epochs on cpu:   8%|█▌                   | 15/200 [00:03<00:44,  4.17epoch/s, loss=7.56, prev_loss=7.52]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.46batch/s]
# Training epochs on cpu:   8%|█▋                   | 16/200 [00:03<00:43,  4.19epoch/s, loss=7.37, prev_loss=7.56]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.73batch/s]
# Training epochs on cpu:   8%|█▊                    | 17/200 [00:04<00:43,  4.18epoch/s, loss=6.7, prev_loss=7.37]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.55batch/s]
# Training epochs on cpu:   9%|█▉                    | 18/200 [00:04<00:44,  4.13epoch/s, loss=7.04, prev_loss=6.7]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 80.26batch/s]
# Training epochs on cpu:  10%|█▉                   | 19/200 [00:04<00:44,  4.10epoch/s, loss=6.95, prev_loss=7.04]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.76batch/s]
# Training epochs on cpu:  10%|██                   | 20/200 [00:04<00:44,  4.02epoch/s, loss=6.31, prev_loss=6.95]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.23batch/s]
# Training epochs on cpu:  10%|██▏                  | 21/200 [00:05<00:45,  3.95epoch/s, loss=6.41, prev_loss=6.31]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.47batch/s]
# Training epochs on cpu:  11%|██▎                  | 22/200 [00:05<00:45,  3.90epoch/s, loss=6.34, prev_loss=6.41]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.79batch/s]
# Training epochs on cpu:  12%|██▍                  | 23/200 [00:05<00:46,  3.85epoch/s, loss=6.31, prev_loss=6.34]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.37batch/s]
# Training epochs on cpu:  12%|██▌                  | 24/200 [00:05<00:45,  3.84epoch/s, loss=6.01, prev_loss=6.31]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.49batch/s]
# Training epochs on cpu:  12%|██▋                  | 25/200 [00:06<00:46,  3.80epoch/s, loss=6.15, prev_loss=6.01]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.99batch/s]
# Training epochs on cpu:  13%|██▋                  | 26/200 [00:06<00:46,  3.75epoch/s, loss=6.17, prev_loss=6.15]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.91batch/s]
# Training epochs on cpu:  14%|██▊                  | 27/200 [00:06<00:45,  3.76epoch/s, loss=6.03, prev_loss=6.17]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.76batch/s]
# Training epochs on cpu:  14%|██▉                  | 28/200 [00:07<00:45,  3.76epoch/s, loss=5.73, prev_loss=6.03]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.13batch/s]
# Training epochs on cpu:  14%|███                  | 29/200 [00:07<00:45,  3.75epoch/s, loss=5.72, prev_loss=5.73]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.75batch/s]
# Training epochs on cpu:  15%|███▎                  | 30/200 [00:07<00:45,  3.74epoch/s, loss=5.9, prev_loss=5.72]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.75batch/s]
# Training epochs on cpu:  16%|███▍                  | 31/200 [00:07<00:44,  3.82epoch/s, loss=5.64, prev_loss=5.9]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 67.56batch/s]
# Training epochs on cpu:  16%|███▎                 | 32/200 [00:08<00:44,  3.78epoch/s, loss=5.64, prev_loss=5.64]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.53batch/s]
# Training epochs on cpu:  16%|███▍                 | 33/200 [00:08<00:44,  3.77epoch/s, loss=5.64, prev_loss=5.64]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.34batch/s]
# Training epochs on cpu:  17%|███▌                 | 34/200 [00:08<00:44,  3.73epoch/s, loss=5.53, prev_loss=5.64]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.50batch/s]
# Training epochs on cpu:  18%|███▋                 | 35/200 [00:08<00:43,  3.83epoch/s, loss=5.42, prev_loss=5.53]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.28batch/s]
# Training epochs on cpu:  18%|███▊                 | 36/200 [00:09<00:42,  3.86epoch/s, loss=5.49, prev_loss=5.42]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.55batch/s]
# Training epochs on cpu:  18%|███▉                 | 37/200 [00:09<00:41,  3.91epoch/s, loss=5.25, prev_loss=5.49]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 87.73batch/s]
# Training epochs on cpu:  19%|███▉                 | 38/200 [00:09<00:40,  4.05epoch/s, loss=5.27, prev_loss=5.25]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.62batch/s]
# Training epochs on cpu:  20%|████                 | 39/200 [00:09<00:40,  4.02epoch/s, loss=5.07, prev_loss=5.27]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.41batch/s]
# Training epochs on cpu:  20%|████▍                 | 40/200 [00:10<00:39,  4.02epoch/s, loss=5.1, prev_loss=5.07]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.25batch/s]
# Training epochs on cpu:  20%|████▌                 | 41/200 [00:10<00:39,  4.02epoch/s, loss=5.47, prev_loss=5.1]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.28batch/s]
# Training epochs on cpu:  21%|████▍                | 42/200 [00:10<00:38,  4.14epoch/s, loss=5.28, prev_loss=5.47]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.89batch/s]
# Training epochs on cpu:  22%|████▌                | 43/200 [00:10<00:37,  4.21epoch/s, loss=5.22, prev_loss=5.28]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.23batch/s]
# Training epochs on cpu:  22%|█████▎                  | 44/200 [00:11<00:37,  4.15epoch/s, loss=5, prev_loss=5.22]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.48batch/s]
# Training epochs on cpu:  22%|█████▍                  | 45/200 [00:11<00:36,  4.20epoch/s, loss=5.11, prev_loss=5]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.73batch/s]
# Training epochs on cpu:  23%|████▊                | 46/200 [00:11<00:37,  4.15epoch/s, loss=4.76, prev_loss=5.11]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.13batch/s]
# Training epochs on cpu:  24%|████▉                | 47/200 [00:11<00:37,  4.12epoch/s, loss=5.06, prev_loss=4.76]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.25batch/s]
# Training epochs on cpu:  24%|█████                | 48/200 [00:12<00:37,  4.07epoch/s, loss=4.88, prev_loss=5.06]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.07batch/s]
# Training epochs on cpu:  24%|█████▏               | 49/200 [00:12<00:37,  4.05epoch/s, loss=4.81, prev_loss=4.88]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.99batch/s]
# Training epochs on cpu:  25%|█████▎               | 50/200 [00:12<00:36,  4.06epoch/s, loss=5.07, prev_loss=4.81]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.45batch/s]
# Training epochs on cpu:  26%|█████▎               | 51/200 [00:12<00:36,  4.10epoch/s, loss=4.89, prev_loss=5.07]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.77batch/s]
# Training epochs on cpu:  26%|█████▍               | 52/200 [00:13<00:36,  4.01epoch/s, loss=4.89, prev_loss=4.89]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.93batch/s]
# Training epochs on cpu:  26%|█████▌               | 53/200 [00:13<00:37,  3.92epoch/s, loss=4.96, prev_loss=4.89]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.03batch/s]
# Training epochs on cpu:  27%|█████▉                | 54/200 [00:13<00:37,  3.85epoch/s, loss=4.6, prev_loss=4.96]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.29batch/s]
# Training epochs on cpu:  28%|██████                | 55/200 [00:13<00:37,  3.82epoch/s, loss=4.76, prev_loss=4.6]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.73batch/s]
# Training epochs on cpu:  28%|█████▉               | 56/200 [00:14<00:37,  3.82epoch/s, loss=4.79, prev_loss=4.76]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.01batch/s]
# Training epochs on cpu:  28%|█████▉               | 57/200 [00:14<00:37,  3.79epoch/s, loss=4.97, prev_loss=4.79]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.04batch/s]
# Training epochs on cpu:  29%|██████               | 58/200 [00:14<00:37,  3.74epoch/s, loss=4.61, prev_loss=4.97]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.30batch/s]
# Training epochs on cpu:  30%|██████▏              | 59/200 [00:14<00:37,  3.71epoch/s, loss=4.57, prev_loss=4.61]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.39batch/s]
# Training epochs on cpu:  30%|██████▎              | 60/200 [00:15<00:37,  3.69epoch/s, loss=4.89, prev_loss=4.57]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.04batch/s]
# Training epochs on cpu:  30%|██████▍              | 61/200 [00:15<00:38,  3.62epoch/s, loss=4.94, prev_loss=4.89]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.14batch/s]
# Training epochs on cpu:  31%|██████▌              | 62/200 [00:15<00:37,  3.65epoch/s, loss=4.91, prev_loss=4.94]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.03batch/s]
# Training epochs on cpu:  32%|██████▌              | 63/200 [00:16<00:37,  3.62epoch/s, loss=4.69, prev_loss=4.91]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.44batch/s]
# Training epochs on cpu:  32%|██████▋              | 64/200 [00:16<00:37,  3.65epoch/s, loss=4.83, prev_loss=4.69]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.27batch/s]
# Training epochs on cpu:  32%|██████▊              | 65/200 [00:16<00:36,  3.68epoch/s, loss=4.73, prev_loss=4.83]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.20batch/s]
# Training epochs on cpu:  33%|██████▉              | 66/200 [00:16<00:36,  3.67epoch/s, loss=4.76, prev_loss=4.73]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.92batch/s]
# Training epochs on cpu:  34%|███████              | 67/200 [00:17<00:35,  3.74epoch/s, loss=4.65, prev_loss=4.76]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.88batch/s]
# Training epochs on cpu:  34%|███████▏             | 68/200 [00:17<00:33,  3.96epoch/s, loss=4.72, prev_loss=4.65]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 91.19batch/s]
# Training epochs on cpu:  34%|███████▌              | 69/200 [00:17<00:32,  4.07epoch/s, loss=4.5, prev_loss=4.72]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.38batch/s]
# Training epochs on cpu:  35%|███████▋              | 70/200 [00:17<00:31,  4.17epoch/s, loss=4.45, prev_loss=4.5]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.29batch/s]
# Training epochs on cpu:  36%|███████▍             | 71/200 [00:18<00:30,  4.21epoch/s, loss=4.59, prev_loss=4.45]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.25batch/s]
# Training epochs on cpu:  36%|███████▌             | 72/200 [00:18<00:29,  4.28epoch/s, loss=4.58, prev_loss=4.59]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 82.74batch/s]
# Training epochs on cpu:  36%|███████▋             | 73/200 [00:18<00:30,  4.23epoch/s, loss=4.69, prev_loss=4.58]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.03batch/s]
# Training epochs on cpu:  37%|███████▊             | 74/200 [00:18<00:30,  4.18epoch/s, loss=4.77, prev_loss=4.69]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.26batch/s]
# Training epochs on cpu:  38%|███████▉             | 75/200 [00:18<00:30,  4.15epoch/s, loss=4.85, prev_loss=4.77]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.01batch/s]
# Training epochs on cpu:  38%|███████▉             | 76/200 [00:19<00:29,  4.24epoch/s, loss=4.59, prev_loss=4.85]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 88.14batch/s]
# Training epochs on cpu:  38%|████████             | 77/200 [00:19<00:29,  4.23epoch/s, loss=4.45, prev_loss=4.59]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 83.54batch/s]
# Training epochs on cpu:  39%|████████▌             | 78/200 [00:19<00:28,  4.33epoch/s, loss=4.5, prev_loss=4.45]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 81.87batch/s]
# Training epochs on cpu:  40%|████████▋             | 79/200 [00:19<00:28,  4.28epoch/s, loss=4.37, prev_loss=4.5]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 88.71batch/s]
# Training epochs on cpu:  40%|████████▍            | 80/200 [00:20<00:28,  4.27epoch/s, loss=4.43, prev_loss=4.37]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.49batch/s]
# Training epochs on cpu:  40%|████████▉             | 81/200 [00:20<00:28,  4.20epoch/s, loss=4.4, prev_loss=4.43]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 89.89batch/s]
# Training epochs on cpu:  41%|█████████             | 82/200 [00:20<00:27,  4.31epoch/s, loss=4.55, prev_loss=4.4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.90batch/s]
# Training epochs on cpu:  42%|████████▋            | 83/200 [00:20<00:26,  4.38epoch/s, loss=4.39, prev_loss=4.55]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 87.36batch/s]
# Training epochs on cpu:  42%|████████▊            | 84/200 [00:21<00:26,  4.42epoch/s, loss=4.54, prev_loss=4.39]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.11batch/s]
# Training epochs on cpu:  42%|████████▉            | 85/200 [00:21<00:26,  4.29epoch/s, loss=4.25, prev_loss=4.54]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 84.71batch/s]
# Training epochs on cpu:  43%|█████████            | 86/200 [00:21<00:26,  4.37epoch/s, loss=4.63, prev_loss=4.25]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.52batch/s]
# Training epochs on cpu:  44%|█████████▏           | 87/200 [00:21<00:26,  4.28epoch/s, loss=4.45, prev_loss=4.63]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.53batch/s]
# Training epochs on cpu:  44%|█████████▋            | 88/200 [00:22<00:26,  4.20epoch/s, loss=4.4, prev_loss=4.45]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.45batch/s]
# Training epochs on cpu:  44%|█████████▊            | 89/200 [00:22<00:26,  4.16epoch/s, loss=4.48, prev_loss=4.4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 84.86batch/s]
# Training epochs on cpu:  45%|█████████▍           | 90/200 [00:22<00:26,  4.17epoch/s, loss=4.32, prev_loss=4.48]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.21batch/s]
# Training epochs on cpu:  46%|█████████▌           | 91/200 [00:22<00:26,  4.14epoch/s, loss=4.35, prev_loss=4.32]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.89batch/s]
# Training epochs on cpu:  46%|█████████▋           | 92/200 [00:22<00:25,  4.20epoch/s, loss=4.23, prev_loss=4.35]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 88.98batch/s]
# Training epochs on cpu:  46%|█████████▊           | 93/200 [00:23<00:24,  4.32epoch/s, loss=4.34, prev_loss=4.23]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.37batch/s]
# Training epochs on cpu:  47%|█████████▊           | 94/200 [00:23<00:25,  4.22epoch/s, loss=4.35, prev_loss=4.34]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.58batch/s]
# Training epochs on cpu:  48%|█████████▉           | 95/200 [00:23<00:24,  4.22epoch/s, loss=4.36, prev_loss=4.35]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.06batch/s]
# Training epochs on cpu:  48%|██████████           | 96/200 [00:23<00:25,  4.14epoch/s, loss=4.16, prev_loss=4.36]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 84.67batch/s]
# Training epochs on cpu:  48%|██████████▏          | 97/200 [00:24<00:24,  4.17epoch/s, loss=4.33, prev_loss=4.16]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 90.77batch/s]
# Training epochs on cpu:  49%|██████████▎          | 98/200 [00:24<00:23,  4.25epoch/s, loss=4.48, prev_loss=4.33]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.99batch/s]
# Training epochs on cpu:  50%|██████████▉           | 99/200 [00:24<00:23,  4.25epoch/s, loss=4.4, prev_loss=4.48]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.48batch/s]
# Training epochs on cpu:  50%|██████████▌          | 100/200 [00:24<00:23,  4.20epoch/s, loss=4.26, prev_loss=4.4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 89.86batch/s]
# Training epochs on cpu:  50%|██████████          | 101/200 [00:25<00:23,  4.25epoch/s, loss=4.23, prev_loss=4.26]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.56batch/s]
# Training epochs on cpu:  51%|██████████▏         | 102/200 [00:25<00:23,  4.21epoch/s, loss=4.16, prev_loss=4.23]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 81.28batch/s]
# Training epochs on cpu:  52%|██████████▎         | 103/200 [00:25<00:22,  4.26epoch/s, loss=4.15, prev_loss=4.16]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 89.61batch/s]
# Training epochs on cpu:  52%|██████████▍         | 104/200 [00:25<00:21,  4.39epoch/s, loss=4.15, prev_loss=4.15]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 85.53batch/s]
# Training epochs on cpu:  52%|██████████▌         | 105/200 [00:25<00:21,  4.43epoch/s, loss=4.18, prev_loss=4.15]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 85.57batch/s]
# Training epochs on cpu:  53%|███████████▏         | 106/200 [00:26<00:21,  4.34epoch/s, loss=4.1, prev_loss=4.18]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.68batch/s]
# Training epochs on cpu:  54%|███████████▏         | 107/200 [00:26<00:21,  4.36epoch/s, loss=4.23, prev_loss=4.1]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 84.59batch/s]
# Training epochs on cpu:  54%|██████████▊         | 108/200 [00:26<00:20,  4.40epoch/s, loss=3.99, prev_loss=4.23]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.29batch/s]
# Training epochs on cpu:  55%|██████████▉         | 109/200 [00:26<00:20,  4.36epoch/s, loss=4.17, prev_loss=3.99]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 88.44batch/s]
# Training epochs on cpu:  55%|███████████         | 110/200 [00:27<00:20,  4.35epoch/s, loss=3.97, prev_loss=4.17]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.23batch/s]
# Training epochs on cpu:  56%|████████████▊          | 111/200 [00:27<00:20,  4.31epoch/s, loss=4, prev_loss=3.97]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.77batch/s]
# Training epochs on cpu:  56%|██████████████▌           | 112/200 [00:27<00:20,  4.22epoch/s, loss=4, prev_loss=4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.14batch/s]
# Training epochs on cpu:  56%|████████████▉          | 113/200 [00:27<00:20,  4.15epoch/s, loss=3.94, prev_loss=4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.11batch/s]
# Training epochs on cpu:  57%|███████████▍        | 114/200 [00:28<00:20,  4.16epoch/s, loss=4.16, prev_loss=3.94]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.09batch/s]
# Training epochs on cpu:  57%|███████████▌        | 115/200 [00:28<00:20,  4.12epoch/s, loss=3.74, prev_loss=4.16]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.43batch/s]
# Training epochs on cpu:  58%|███████████▌        | 116/200 [00:28<00:20,  4.16epoch/s, loss=3.95, prev_loss=3.74]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.71batch/s]
# Training epochs on cpu:  58%|███████████▋        | 117/200 [00:28<00:19,  4.24epoch/s, loss=3.77, prev_loss=3.95]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.08batch/s]
# Training epochs on cpu:  59%|███████████▊        | 118/200 [00:29<00:19,  4.16epoch/s, loss=3.95, prev_loss=3.77]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.95batch/s]
# Training epochs on cpu:  60%|████████████▍        | 119/200 [00:29<00:19,  4.14epoch/s, loss=3.8, prev_loss=3.95]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 86.26batch/s]
# Training epochs on cpu:  60%|████████████▌        | 120/200 [00:29<00:18,  4.26epoch/s, loss=3.84, prev_loss=3.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.96batch/s]
# Training epochs on cpu:  60%|████████████        | 121/200 [00:29<00:18,  4.20epoch/s, loss=3.93, prev_loss=3.84]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.26batch/s]
# Training epochs on cpu:  61%|████████████▊        | 122/200 [00:30<00:18,  4.17epoch/s, loss=3.8, prev_loss=3.93]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.37batch/s]
# Training epochs on cpu:  62%|████████████▉        | 123/200 [00:30<00:18,  4.19epoch/s, loss=3.93, prev_loss=3.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 89.55batch/s]
# Training epochs on cpu:  62%|████████████▍       | 124/200 [00:30<00:17,  4.35epoch/s, loss=4.02, prev_loss=3.93]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.47batch/s]
# Training epochs on cpu:  62%|████████████▌       | 125/200 [00:30<00:17,  4.32epoch/s, loss=3.74, prev_loss=4.02]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 85.56batch/s]
# Training epochs on cpu:  63%|████████████▌       | 126/200 [00:30<00:17,  4.30epoch/s, loss=3.89, prev_loss=3.74]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.32batch/s]
# Training epochs on cpu:  64%|████████████▋       | 127/200 [00:31<00:17,  4.23epoch/s, loss=3.83, prev_loss=3.89]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.99batch/s]
# Training epochs on cpu:  64%|████████████▊       | 128/200 [00:31<00:17,  4.16epoch/s, loss=4.06, prev_loss=3.83]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.58batch/s]
# Training epochs on cpu:  64%|████████████▉       | 129/200 [00:31<00:17,  4.08epoch/s, loss=3.88, prev_loss=4.06]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 87.87batch/s]
# Training epochs on cpu:  65%|█████████████       | 130/200 [00:31<00:16,  4.14epoch/s, loss=3.75, prev_loss=3.88]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.58batch/s]
# Training epochs on cpu:  66%|█████████████       | 131/200 [00:32<00:17,  3.94epoch/s, loss=3.73, prev_loss=3.75]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.58batch/s]
# Training epochs on cpu:  66%|█████████████▏      | 132/200 [00:32<00:17,  3.90epoch/s, loss=3.63, prev_loss=3.73]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.60batch/s]
# Training epochs on cpu:  66%|█████████████▎      | 133/200 [00:32<00:17,  3.78epoch/s, loss=3.83, prev_loss=3.63]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.90batch/s]
# Training epochs on cpu:  67%|█████████████▍      | 134/200 [00:33<00:17,  3.81epoch/s, loss=3.64, prev_loss=3.83]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.52batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.95batch/s]
# Training epochs on cpu:  68%|█████████████▌      | 135/200 [00:33<00:17,  3.65epoch/s, loss=3.76, prev_loss=3.64]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.51batch/s]
# Training epochs on cpu:  68%|█████████████▌      | 136/200 [00:33<00:17,  3.74epoch/s, loss=3.71, prev_loss=3.76]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.06batch/s]
# Training epochs on cpu:  68%|██████████████▍      | 137/200 [00:33<00:16,  3.73epoch/s, loss=3.7, prev_loss=3.71]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.34batch/s]
# Training epochs on cpu:  69%|██████████████▍      | 138/200 [00:34<00:16,  3.82epoch/s, loss=3.76, prev_loss=3.7]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.66batch/s]
# ...
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 87.76batch/s]
# Training epochs on cpu:  78%|████████████████▍    | 157/200 [00:38<00:09,  4.32epoch/s, loss=3.4, prev_loss=3.52]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.60batch/s]
# Training epochs on cpu:  79%|████████████████▌    | 158/200 [00:38<00:09,  4.25epoch/s, loss=3.25, prev_loss=3.4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.66batch/s]
# Training epochs on cpu:  80%|███████████████▉    | 159/200 [00:39<00:09,  4.16epoch/s, loss=3.39, prev_loss=3.25]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 83.10batch/s]
# Training epochs on cpu:  80%|████████████████    | 160/200 [00:39<00:09,  4.15epoch/s, loss=3.39, prev_loss=3.39]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.34batch/s]
# Training epochs on cpu:  80%|████████████████    | 161/200 [00:39<00:09,  4.12epoch/s, loss=3.47, prev_loss=3.39]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 87.88batch/s]
# Training epochs on cpu:  81%|████████████████▏   | 162/200 [00:39<00:09,  4.18epoch/s, loss=3.26, prev_loss=3.47]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.41batch/s]
# Training epochs on cpu:  82%|████████████████▎   | 163/200 [00:40<00:09,  4.10epoch/s, loss=3.58, prev_loss=3.26]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.01batch/s]
# Training epochs on cpu:  82%|████████████████▍   | 164/200 [00:40<00:08,  4.03epoch/s, loss=3.42, prev_loss=3.58]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.74batch/s]
# Training epochs on cpu:  82%|████████████████▌   | 165/200 [00:40<00:08,  3.95epoch/s, loss=3.38, prev_loss=3.42]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.07batch/s]
# Training epochs on cpu:  83%|████████████████▌   | 166/200 [00:40<00:08,  3.87epoch/s, loss=3.18, prev_loss=3.38]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.25batch/s]
# Training epochs on cpu:  84%|█████████████████▌   | 167/200 [00:41<00:08,  3.79epoch/s, loss=3.4, prev_loss=3.18]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.79batch/s]
# Training epochs on cpu:  84%|█████████████████▋   | 168/200 [00:41<00:08,  3.81epoch/s, loss=3.17, prev_loss=3.4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.88batch/s]
# Training epochs on cpu:  84%|████████████████▉   | 169/200 [00:41<00:08,  3.72epoch/s, loss=3.34, prev_loss=3.17]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.58batch/s]
# Training epochs on cpu:  85%|█████████████████   | 170/200 [00:41<00:08,  3.75epoch/s, loss=3.21, prev_loss=3.34]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.46batch/s]
# Training epochs on cpu:  86%|█████████████████   | 171/200 [00:42<00:07,  3.74epoch/s, loss=3.15, prev_loss=3.21]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.03batch/s]
# Training epochs on cpu:  86%|█████████████████▏  | 172/200 [00:42<00:07,  3.79epoch/s, loss=3.33, prev_loss=3.15]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.09batch/s]
# Training epochs on cpu:  86%|█████████████████▎  | 173/200 [00:42<00:06,  3.87epoch/s, loss=3.27, prev_loss=3.33]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.66batch/s]
# Training epochs on cpu:  87%|█████████████████▍  | 174/200 [00:42<00:06,  3.82epoch/s, loss=3.15, prev_loss=3.27]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.53batch/s]
# Training epochs on cpu:  88%|█████████████████▌  | 175/200 [00:43<00:06,  3.84epoch/s, loss=3.07, prev_loss=3.15]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.29batch/s]
# Training epochs on cpu:  88%|█████████████████▌  | 176/200 [00:43<00:06,  3.84epoch/s, loss=3.12, prev_loss=3.07]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.45batch/s]
# Training epochs on cpu:  88%|█████████████████▋  | 177/200 [00:43<00:06,  3.82epoch/s, loss=3.21, prev_loss=3.12]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.82batch/s]
# Training epochs on cpu:  89%|█████████████████▊  | 178/200 [00:44<00:05,  3.82epoch/s, loss=3.12, prev_loss=3.21]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.61batch/s]
# Training epochs on cpu:  90%|█████████████████▉  | 179/200 [00:44<00:05,  3.81epoch/s, loss=3.09, prev_loss=3.12]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 80.69batch/s]
# Training epochs on cpu:  90%|██████████████████  | 180/200 [00:44<00:05,  3.96epoch/s, loss=3.14, prev_loss=3.09]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.34batch/s]
# Training epochs on cpu:  90%|██████████████████  | 181/200 [00:44<00:04,  3.99epoch/s, loss=3.11, prev_loss=3.14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.44batch/s]
# Training epochs on cpu:  91%|██████████████████▏ | 182/200 [00:45<00:04,  3.96epoch/s, loss=3.06, prev_loss=3.11]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.40batch/s]
# Training epochs on cpu:  92%|██████████████████▎ | 183/200 [00:45<00:04,  3.99epoch/s, loss=3.07, prev_loss=3.06]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 83.18batch/s]
# Training epochs on cpu:  92%|██████████████████▍ | 184/200 [00:45<00:03,  4.05epoch/s, loss=2.89, prev_loss=3.07]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.24batch/s]
# Training epochs on cpu:  92%|██████████████████▌ | 185/200 [00:45<00:03,  4.14epoch/s, loss=3.14, prev_loss=2.89]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.94batch/s]
# Training epochs on cpu:  93%|██████████████████▌ | 186/200 [00:45<00:03,  4.13epoch/s, loss=3.14, prev_loss=3.14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.29batch/s]
# Training epochs on cpu:  94%|██████████████████▋ | 187/200 [00:46<00:03,  4.13epoch/s, loss=3.14, prev_loss=3.14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.92batch/s]
# Training epochs on cpu:  94%|██████████████████▊ | 188/200 [00:46<00:02,  4.05epoch/s, loss=2.99, prev_loss=3.14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.01batch/s]
# Training epochs on cpu:  94%|███████████████████▊ | 189/200 [00:46<00:02,  4.04epoch/s, loss=2.9, prev_loss=2.99]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.42batch/s]
# Training epochs on cpu:  95%|███████████████████▉ | 190/200 [00:46<00:02,  3.96epoch/s, loss=2.92, prev_loss=2.9]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.00batch/s]
# Training epochs on cpu:  96%|███████████████████ | 191/200 [00:47<00:02,  3.93epoch/s, loss=2.98, prev_loss=2.92]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.85batch/s]
# Training epochs on cpu:  96%|███████████████████▏| 192/200 [00:47<00:02,  3.85epoch/s, loss=2.97, prev_loss=2.98]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.50batch/s]
# Training epochs on cpu:  96%|███████████████████▎| 193/200 [00:47<00:01,  3.76epoch/s, loss=2.92, prev_loss=2.97]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 84.14batch/s]
# Training epochs on cpu:  97%|███████████████████▍| 194/200 [00:48<00:01,  3.91epoch/s, loss=2.92, prev_loss=2.92]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.90batch/s]
# Training epochs on cpu:  98%|███████████████████▌| 195/200 [00:48<00:01,  3.73epoch/s, loss=3.08, prev_loss=2.92]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.69batch/s]
# Training epochs on cpu:  98%|███████████████████▌| 196/200 [00:48<00:01,  3.75epoch/s, loss=2.87, prev_loss=3.08]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.58batch/s]
# Training epochs on cpu:  98%|████████████████████▋| 197/200 [00:48<00:00,  3.74epoch/s, loss=2.8, prev_loss=2.87]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 49.25batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 60.60batch/s]
# Training epochs on cpu:  99%|████████████████████▊| 198/200 [00:49<00:00,  3.58epoch/s, loss=3.03, prev_loss=2.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.82batch/s]
# Training epochs on cpu: 100%|███████████████████▉| 199/200 [00:49<00:00,  3.64epoch/s, loss=2.88, prev_loss=3.03]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.95batch/s]
# Training epochs on cpu: 100%|████████████████████| 200/200 [00:49<00:00,  4.02epoch/s, loss=3.07, prev_loss=2.88]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# WARNING:pykeen.utils:The filtered setting was enabled, but there were no `additional_filter_triples`
# given. This means you probably forgot to pass (at least) the training triples. Try:
#
#     additional_filter_triples=[dataset.training.mapped_triples]
#
# Or if you want to use the Bordes et al. (2013) approach to filtering, do:
#
#     additional_filter_triples=[
#         dataset.training.mapped_triples,
#         dataset.validation.mapped_triples,
#     ]
#
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|███████████████████████████████████████████████████| 159/159 [00:00<00:00, 1.12ktriple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.15s seconds
# 0.0027478434754617557

# %% [markdown]
# ### Exercise 3
#
# Try changing the parameters of your training process. See if you obtain a better model in terms of average loss. Save it as ./data/best_model.pkl. Which parameters work best for the dataset?
#
# Now use the training and test set you created in Exercise 2. Which loss you obtain, and for which parameters?
#
# Remember to save each model locally with a different name, so you can find them back.

# %%
### your code here

# %% [markdown]
# # 4. Evaluating the Model

# %% [markdown]
# ### Metrics

# %% [markdown]
# We can now get some evaluation metrics for our model, they were already computed during evaluation time as part of the pipeline, and print them out.
#
# We are going to use the following evaluation metrics:
# - <i>mrr</i> (mean reciprocal rank) : this function computes the mean of the reciprocal of elements of a vector of rankings ranks
# - <i>hits_at_n</i> : this function computes how many elements of a vector of rankings ranks make it to the $top_n$ positions.
#
# NB : The choice of which _N_ makes more sense depends on the application and the size of the dataset.

# %%
pipeline_result.get_metric('hits_at_10')
# Out:
# 0.03773584905660377

# %%
# from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score

mrr = pipeline_result.get_metric('mrr')
print("MRR: %.4f" % (mrr))
print()

hits_10 = pipeline_result.get_metric('hits_at_10')
print("Hits@10: %.6f" % (hits_10))
print("Interpretation: on average, the model guessed the correct subject or object %.1f%% of the time when considering the top-10 better ranked triples.\n" % (hits_10*100))

hits_3 = pipeline_result.get_metric('hits_at_3')
print("Hits@3: %.6f" % (hits_3))
print("Interpretation: on average, the model guessed the correct subject or object %.1f%% of the time when considering the top-3 better ranked triples.\n" % (hits_3*100))

# hits_1 = hits_at_n_score(ranks, n=1)
# print("Hits@1: %.2f" % (hits_1))
# print("Interpretation: on average, the model guessed the correct subject or object %.1f%% of the time when considering the top-1 better ranked triples.\n" % (hits_1*100))
# Out:
# MRR: 0.0377
#
# Hits@10: 0.037736
# Interpretation: on average, the model guessed the correct subject or object 3.8% of the time when considering the top-10 better ranked triples.
#
# Hits@3: 0.003145
# Interpretation: on average, the model guessed the correct subject or object 0.3% of the time when considering the top-3 better ranked triples.

# %% [markdown]
# ### Exercise 4
#
# Evaluate the models you created before (different set sizes, different parameters). Summarise your results in a table.

# %%
### your code here

# %% [markdown]
# # 5. Link Prediction

# %% [markdown]
# Link prediction allows to infer missing links in a graph. This has many real-world use cases, such as predicting connections between people in a social network, interactions between proteins in a biological network, and music recommendation based on prior user taste.
#
# In our case, we are going to see which of the following candidate statements is more likely to be true. Note that the candidate statements below are made up, i.e. they are not in the original dataset.

# %%
X_unseen = np.array([
    ['Jorah Mormont', 'SPOUSE', 'Daenerys Targaryen'],
    ['Tyrion Lannister', 'SPOUSE', 'Missandei'],
    ["King's Landing", 'SEAT_OF', 'House Lannister of Casterly Rock'],
    ['Sansa Stark', 'SPOUSE', 'Petyr Baelish'],
    ['Daenerys Targaryen', 'SPOUSE', 'Jon Snow'],
    ['Daenerys Targaryen', 'SPOUSE', 'Craster'],
    ['House Stark of Winterfell', 'IN_REGION', 'The North'],
    ['House Stark of Winterfell', 'IN_REGION', 'Dorne'],
    ['House Tyrell of Highgarden', 'IN_REGION', 'Beyond the Wall'],
    ['Brandon Stark', 'ALLIED_WITH', 'House Stark of Winterfell'],
    ['Brandon Stark', 'ALLIED_WITH', 'House Lannister of Casterly Rock'],    
    ['Rhaegar Targaryen', 'PARENT_OF', 'Jon Snow'],
    ['House Hutcheson', 'SWORN_TO', 'House Tyrell of Highgarden'],
    ['Daenerys Targaryen', 'ALLIED_WITH', 'House Stark of Winterfell'],
    ['Daenerys Targaryen', 'ALLIED_WITH', 'House Lannister of Casterly Rock'],
    ['Jaime Lannister', 'PARENT_OF', 'Myrcella Baratheon'],
    ['Robert I Baratheon', 'PARENT_OF', 'Myrcella Baratheon'],
    ['Cersei Lannister', 'PARENT_OF', 'Myrcella Baratheon'],
    ['Cersei Lannister', 'PARENT_OF', 'Brandon Stark'],
    ["Tywin Lannister", 'PARENT_OF', 'Jaime Lannister'],
    ["Missandei", 'SPOUSE', 'Grey Worm'],
    ["Brienne of Tarth", 'SPOUSE', 'Jaime Lannister']
])

## we need to map the above triples to the id's which we used in our training/testing.
## This information is stored in the triple factory "got", which we created at the beginning

# unseen_filter = np.array(list({tuple(i) for i in np.vstack((positives_filter, X_unseen))}))
#     filter_triples=unseen_filter,   # Corruption strategy filter defined above 
#     corrupt_side = 's+o',
#     use_default_protocol=False, # corrupt subj and obj separately while evaluating
#     verbose=True
# )

# %%
from pykeen import predict
# from pykeen.predict import predict_triples

# got_unseen = triples.get_mapped_tripples(X_unseen,factory=got)
pack = predict.predict_triples(model=pipeline_result.model, triples=X_unseen, triples_factory=got)
# Out:
# WARNING:torch_max_mem.api:Using maximize_memory_utilization on non-CUDA tensors. This may lead to undocumented crashes due to CPU OOM killer.

# %%
# scores are real numbers that need to be translated into probabilities [0,1] 
# for this, we use the expit transform.

from scipy.special import expit
processed_results = pack.process().df
# print(processed_results)

probs = expit(processed_results['score'])
# print(probs)

processed_results['prob'] = probs
processed_results['triple'] = list(zip([' '.join(x) for x in X_unseen]))

# processed_results
pd.DataFrame(list(zip([' '.join(x) for x in X_unseen],  
                      np.squeeze(processed_results['score']),
                      np.squeeze(probs))), 
             columns=['statement', 'score', 'prob']).sort_values("score")
# Out:
#                                             statement      score          prob
# 6       House Stark of Winterfell IN_REGION The North -41.942921  6.087248e-19
# 19          Tywin Lannister PARENT_OF Jaime Lannister -39.054153  1.093948e-17
# 2   King's Landing SEAT_OF House Lannister of Cast... -36.651661  1.208888e-16
# 7           House Stark of Winterfell IN_REGION Dorne -30.721342  4.548735e-14
# 5                   Daenerys Targaryen SPOUSE Craster -12.153019  5.272404e-06
# 12  House Hutcheson SWORN_TO House Tyrell of Highg... -10.830919  1.977803e-05
# 15       Jaime Lannister PARENT_OF Myrcella Baratheon  -9.354927  8.653050e-05
# 4                  Daenerys Targaryen SPOUSE Jon Snow  -7.080840  8.403595e-04
# 14  Daenerys Targaryen ALLIED_WITH House Lannister...  -1.801785  1.416339e-01
# 8   House Tyrell of Highgarden IN_REGION Beyond th...  -1.429604  1.931604e-01
# 17      Cersei Lannister PARENT_OF Myrcella Baratheon   3.841900  9.789978e-01
# 9   Brandon Stark ALLIED_WITH House Stark of Winte...   5.767032  9.968808e-01
# 18           Cersei Lannister PARENT_OF Brandon Stark   6.562113  9.985891e-01
# 16    Robert I Baratheon PARENT_OF Myrcella Baratheon  15.615231  9.999999e-01
# 21            Brienne of Tarth SPOUSE Jaime Lannister  15.665249  9.999999e-01
# 11               Rhaegar Targaryen PARENT_OF Jon Snow  20.926872  1.000000e+00
# 13  Daenerys Targaryen ALLIED_WITH House Stark of ...  21.832220  1.000000e+00
# 0             Jorah Mormont SPOUSE Daenerys Targaryen  28.516291  1.000000e+00
# 20                         Missandei SPOUSE Grey Worm  30.816845  1.000000e+00
# 10  Brandon Stark ALLIED_WITH House Lannister of C...  37.382107  1.000000e+00
# 3                    Sansa Stark SPOUSE Petyr Baelish  41.065468  1.000000e+00
# 1                   Tyrion Lannister SPOUSE Missandei  48.201309  1.000000e+00

# %% [markdown]
# NB : the probabilities are not calibrated in any sense. To calibrate them, one may use a procedure such as [Platt scaling](https://en.wikipedia.org/wiki/Platt_scaling) or [Isotonic regression](https://en.wikipedia.org/wiki/Isotonic_regression). The challenge is to define what is a true triple and what is a false one, as the calibration of the probability of a triple being true depends on the base rate of positives and negatives.

# %% [markdown]
# ### Exercise 5
#
# Analyse the results in the tables. Some predicted links are very likely to be true, others  capture things that never really happened. Can you spot which ones?

# %% [markdown]
# # 6 Visualisation

# %% [markdown]
# [Tensorboard](https://www.tensorflow.org/tensorboard) allows to dig into the workings of our model, plot how it is learning, and visualize [high-dimensional embeddings](https://projector.tensorflow.org/). See [this tutorial](https://www.tensorflow.org/tensorboard/get_started) to get started with Tensorflow and see [here](https://pykeen.readthedocs.io/en/stable/tutorial/trackers/using_tensorboard.html) for Tensorboard with PyKEEN.
#
# First ytou neeed to start the tensorboard web application from the command line with
#
# $ tensorboard --logdir=~/.data/pykeen/logs/tensorboard/
#
# and then we can add tensorboard as the result_tracker in our pipeline.

# %%
pipeline_result = pipeline(
    model='ComplEx',
    training=got_training,
    testing=got_testing,
    training_kwargs=dict(
        num_epochs=200
    ),
    dimensions=150,
    optimizer='adam',
    optimizer_kwargs={'lr':1e-3},
    loss='pairwisehinge', 
    regularizer='LP', 
    regularizer_kwargs={'p':3, 'weight':1e-5}, 
    negative_sampler='basic',
    negative_sampler_kwargs=dict(
        filtered=True,
    ),
    result_tracker='tensorboard'
)
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 2597939539.
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# Training epochs on cpu:   0%|                                                         | 0/200 [00:00<?, ?epoch/s]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 95.82batch/s]
# Training epochs on cpu:   0%|                       | 1/200 [00:00<00:55,  3.62epoch/s, loss=16.2, prev_loss=nan]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.78batch/s]
# Training epochs on cpu:   1%|▏                     | 2/200 [00:00<00:56,  3.53epoch/s, loss=16.3, prev_loss=16.2]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 87.85batch/s]
# Training epochs on cpu:   2%|▎                     | 3/200 [00:00<00:53,  3.66epoch/s, loss=15.4, prev_loss=16.3]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 93.14batch/s]
# Training epochs on cpu:   2%|▍                     | 4/200 [00:01<00:52,  3.77epoch/s, loss=15.1, prev_loss=15.4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 83.15batch/s]
# Training epochs on cpu:   2%|▌                     | 5/200 [00:01<00:52,  3.75epoch/s, loss=14.2, prev_loss=15.1]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.64batch/s]
# Training epochs on cpu:   3%|▋                     | 6/200 [00:01<00:53,  3.62epoch/s, loss=13.3, prev_loss=14.2]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.21batch/s]
# Training epochs on cpu:   4%|▊                     | 7/200 [00:01<00:54,  3.52epoch/s, loss=13.9, prev_loss=13.3]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 83.80batch/s]
# Training epochs on cpu:   4%|▉                     | 8/200 [00:02<00:55,  3.48epoch/s, loss=12.1, prev_loss=13.9]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 82.55batch/s]
# Training epochs on cpu:   4%|▉                     | 9/200 [00:02<00:55,  3.41epoch/s, loss=12.4, prev_loss=12.1]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.27batch/s]
# Training epochs on cpu:   5%|█                    | 10/200 [00:02<00:57,  3.29epoch/s, loss=11.8, prev_loss=12.4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.28batch/s]
# Training epochs on cpu:   6%|█▏                   | 11/200 [00:03<00:57,  3.30epoch/s, loss=11.8, prev_loss=11.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 80.43batch/s]
# Training epochs on cpu:   6%|█▎                   | 12/200 [00:03<00:57,  3.28epoch/s, loss=11.7, prev_loss=11.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.01batch/s]
# Training epochs on cpu:   6%|█▎                   | 13/200 [00:03<00:59,  3.15epoch/s, loss=10.9, prev_loss=11.7]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.11batch/s]
# Training epochs on cpu:   7%|█▍                   | 14/200 [00:04<01:01,  3.03epoch/s, loss=10.8, prev_loss=10.9]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 66.97batch/s]
# Training epochs on cpu:   8%|█▌                   | 15/200 [00:04<01:02,  2.97epoch/s, loss=10.5, prev_loss=10.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.51batch/s]
# Training epochs on cpu:   8%|█▋                   | 16/200 [00:04<01:02,  2.93epoch/s, loss=10.1, prev_loss=10.5]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.96batch/s]
# Training epochs on cpu:   8%|█▊                   | 17/200 [00:05<01:03,  2.88epoch/s, loss=9.09, prev_loss=10.1]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.32batch/s]
# Training epochs on cpu:   9%|█▉                   | 18/200 [00:05<01:04,  2.82epoch/s, loss=9.33, prev_loss=9.09]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.28batch/s]
# Training epochs on cpu:  10%|█▉                   | 19/200 [00:05<01:00,  2.98epoch/s, loss=8.81, prev_loss=9.33]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.46batch/s]
# Training epochs on cpu:  10%|██                   | 20/200 [00:06<00:57,  3.12epoch/s, loss=8.74, prev_loss=8.81]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 70.85batch/s]
# Training epochs on cpu:  10%|██▏                  | 21/200 [00:06<00:56,  3.16epoch/s, loss=8.83, prev_loss=8.74]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 78.61batch/s]
# Training epochs on cpu:  11%|██▎                  | 22/200 [00:06<00:55,  3.18epoch/s, loss=7.81, prev_loss=8.83]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.47batch/s]
# Training epochs on cpu:  12%|██▌                   | 23/200 [00:07<00:55,  3.18epoch/s, loss=8.3, prev_loss=7.81]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.68batch/s]
# Training epochs on cpu:  12%|██▋                   | 24/200 [00:07<00:55,  3.18epoch/s, loss=7.97, prev_loss=8.3]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.31batch/s]
# Training epochs on cpu:  12%|██▋                  | 25/200 [00:07<00:55,  3.16epoch/s, loss=7.21, prev_loss=7.97]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.28batch/s]
# Training epochs on cpu:  13%|██▋                  | 26/200 [00:08<00:54,  3.18epoch/s, loss=6.98, prev_loss=7.21]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 79.63batch/s]
# Training epochs on cpu:  14%|██▊                  | 27/200 [00:08<00:53,  3.22epoch/s, loss=7.01, prev_loss=6.98]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.82batch/s]
# Training epochs on cpu:  14%|██▉                  | 28/200 [00:08<00:54,  3.16epoch/s, loss=6.58, prev_loss=7.01]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.68batch/s]
# Training epochs on cpu:  14%|███                  | 29/200 [00:09<00:56,  3.04epoch/s, loss=6.57, prev_loss=6.58]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.01batch/s]
# Training epochs on cpu:  15%|███▎                  | 30/200 [00:09<00:57,  2.96epoch/s, loss=5.6, prev_loss=6.57]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.94batch/s]
# Training epochs on cpu:  16%|███▍                  | 31/200 [00:09<00:57,  2.96epoch/s, loss=6.36, prev_loss=5.6]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.89batch/s]
# Training epochs on cpu:  16%|███▎                 | 32/200 [00:10<00:58,  2.90epoch/s, loss=5.83, prev_loss=6.36]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.65batch/s]
# Training epochs on cpu:  16%|███▍                 | 33/200 [00:10<00:57,  2.88epoch/s, loss=5.76, prev_loss=5.83]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.59batch/s]
# Training epochs on cpu:  17%|███▌                 | 34/200 [00:10<00:57,  2.87epoch/s, loss=5.57, prev_loss=5.76]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.56batch/s]
# Training epochs on cpu:  18%|███▋                 | 35/200 [00:11<00:56,  2.92epoch/s, loss=5.37, prev_loss=5.57]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.17batch/s]
# Training epochs on cpu:  18%|███▊                 | 36/200 [00:11<00:56,  2.91epoch/s, loss=5.35, prev_loss=5.37]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.08batch/s]
# Training epochs on cpu:  18%|███▉                 | 37/200 [00:11<00:56,  2.87epoch/s, loss=5.15, prev_loss=5.35]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.59batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 59.82batch/s]
# Training epochs on cpu:  19%|███▉                 | 38/200 [00:12<00:57,  2.80epoch/s, loss=5.24, prev_loss=5.15]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.69batch/s]
# Training epochs on cpu:  20%|████                 | 39/200 [00:12<00:58,  2.76epoch/s, loss=4.91, prev_loss=5.24]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.18batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.54batch/s]
# Training epochs on cpu:  20%|████▏                | 40/200 [00:13<00:59,  2.68epoch/s, loss=5.09, prev_loss=4.91]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.87batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.49batch/s]
# Training epochs on cpu:  20%|████▎                | 41/200 [00:13<01:00,  2.63epoch/s, loss=4.81, prev_loss=5.09]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.68batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.79batch/s]
# Training epochs on cpu:  21%|████▍                | 42/200 [00:13<01:00,  2.60epoch/s, loss=4.43, prev_loss=4.81]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.35batch/s]
# Training epochs on cpu:  22%|████▌                | 43/200 [00:14<01:00,  2.61epoch/s, loss=3.97, prev_loss=4.43]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.30batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.16batch/s]
# Training epochs on cpu:  22%|█████▎                  | 44/200 [00:14<01:01,  2.55epoch/s, loss=4, prev_loss=3.97]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.51batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.00batch/s]
# Training epochs on cpu:  22%|█████▍                  | 45/200 [00:14<01:01,  2.54epoch/s, loss=4.02, prev_loss=4]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.75batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.91batch/s]
# Training epochs on cpu:  23%|█████                 | 46/200 [00:15<01:00,  2.53epoch/s, loss=3.8, prev_loss=4.02]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.22batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.74batch/s]
# Training epochs on cpu:  24%|█████▏                | 47/200 [00:15<00:59,  2.56epoch/s, loss=3.93, prev_loss=3.8]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.18batch/s]
# Training epochs on cpu:  24%|█████                | 48/200 [00:16<00:57,  2.66epoch/s, loss=3.56, prev_loss=3.93]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.28batch/s]
# Training epochs on cpu:  24%|█████▏               | 49/200 [00:16<00:54,  2.75epoch/s, loss=3.44, prev_loss=3.56]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.39batch/s]
# Training epochs on cpu:  25%|█████▎               | 50/200 [00:16<00:54,  2.74epoch/s, loss=3.65, prev_loss=3.44]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.52batch/s]
# Training epochs on cpu:  26%|█████▎               | 51/200 [00:17<00:55,  2.71epoch/s, loss=3.29, prev_loss=3.65]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.95batch/s]
# Training epochs on cpu:  26%|█████▍               | 52/200 [00:17<00:53,  2.76epoch/s, loss=3.34, prev_loss=3.29]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.31batch/s]
# Training epochs on cpu:  26%|█████▌               | 53/200 [00:17<00:50,  2.88epoch/s, loss=3.52, prev_loss=3.34]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.08batch/s]
# Training epochs on cpu:  27%|█████▋               | 54/200 [00:18<00:48,  3.00epoch/s, loss=3.13, prev_loss=3.52]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.03batch/s]
# Training epochs on cpu:  28%|█████▊               | 55/200 [00:18<00:49,  2.93epoch/s, loss=2.99, prev_loss=3.13]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.86batch/s]
# Training epochs on cpu:  28%|██████▏               | 56/200 [00:18<00:49,  2.91epoch/s, loss=2.9, prev_loss=2.99]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 66.81batch/s]
# Training epochs on cpu:  28%|██████▎               | 57/200 [00:19<00:48,  2.95epoch/s, loss=2.93, prev_loss=2.9]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.09batch/s]
# Training epochs on cpu:  29%|██████               | 58/200 [00:19<00:47,  2.99epoch/s, loss=2.68, prev_loss=2.93]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.35batch/s]
# Training epochs on cpu:  30%|██████▏              | 59/200 [00:19<00:47,  2.96epoch/s, loss=2.75, prev_loss=2.68]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.37batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.30batch/s]
# Training epochs on cpu:  30%|██████▎              | 60/200 [00:20<00:49,  2.86epoch/s, loss=2.76, prev_loss=2.75]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.07batch/s]
# Training epochs on cpu:  30%|██████▍              | 61/200 [00:20<00:48,  2.86epoch/s, loss=2.62, prev_loss=2.76]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 66.68batch/s]
# Training epochs on cpu:  31%|██████▌              | 62/200 [00:20<00:47,  2.90epoch/s, loss=2.33, prev_loss=2.62]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 67.10batch/s]
# Training epochs on cpu:  32%|██████▌              | 63/200 [00:21<00:47,  2.91epoch/s, loss=2.45, prev_loss=2.33]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.81batch/s]
# Training epochs on cpu:  32%|██████▋              | 64/200 [00:21<00:46,  2.90epoch/s, loss=2.51, prev_loss=2.45]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.90batch/s]
# Training epochs on cpu:  32%|██████▊              | 65/200 [00:21<00:47,  2.85epoch/s, loss=2.39, prev_loss=2.51]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.87batch/s]
# Training epochs on cpu:  33%|██████▉              | 66/200 [00:22<00:45,  2.94epoch/s, loss=2.41, prev_loss=2.39]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.47batch/s]
# Training epochs on cpu:  34%|███████              | 67/200 [00:22<00:45,  2.93epoch/s, loss=2.23, prev_loss=2.41]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.25batch/s]
# Training epochs on cpu:  34%|███████▏             | 68/200 [00:22<00:45,  2.88epoch/s, loss=2.48, prev_loss=2.23]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.69batch/s]
# Training epochs on cpu:  34%|███████▏             | 69/200 [00:23<00:45,  2.88epoch/s, loss=2.21, prev_loss=2.48]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.53batch/s]
# Training epochs on cpu:  35%|███████▋              | 70/200 [00:23<00:44,  2.90epoch/s, loss=2.1, prev_loss=2.21]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.33batch/s]
# Training epochs on cpu:  36%|███████▊              | 71/200 [00:24<00:44,  2.91epoch/s, loss=2.13, prev_loss=2.1]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.57batch/s]
# Training epochs on cpu:  36%|███████▌             | 72/200 [00:24<00:43,  2.92epoch/s, loss=1.99, prev_loss=2.13]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.51batch/s]
# Training epochs on cpu:  36%|███████▋             | 73/200 [00:24<00:44,  2.83epoch/s, loss=2.12, prev_loss=1.99]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 67.26batch/s]
# Training epochs on cpu:  37%|███████▊             | 74/200 [00:25<00:44,  2.83epoch/s, loss=1.84, prev_loss=2.12]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 73.50batch/s]
# Training epochs on cpu:  38%|███████▉             | 75/200 [00:25<00:43,  2.89epoch/s, loss=1.86, prev_loss=1.84]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 66.68batch/s]
# Training epochs on cpu:  38%|███████▉             | 76/200 [00:25<00:41,  2.98epoch/s, loss=1.72, prev_loss=1.86]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.37batch/s]
# Training epochs on cpu:  38%|████████             | 77/200 [00:26<00:42,  2.92epoch/s, loss=1.58, prev_loss=1.72]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 71.46batch/s]
# Training epochs on cpu:  39%|████████▏            | 78/200 [00:26<00:42,  2.90epoch/s, loss=1.69, prev_loss=1.58]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.52batch/s]
# Training epochs on cpu:  40%|████████▎            | 79/200 [00:26<00:41,  2.92epoch/s, loss=1.78, prev_loss=1.69]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.47batch/s]
# Training epochs on cpu:  40%|████████▍            | 80/200 [00:27<00:41,  2.89epoch/s, loss=1.85, prev_loss=1.78]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.62batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.80batch/s]
# Training epochs on cpu:  40%|████████▌            | 81/200 [00:27<00:43,  2.73epoch/s, loss=1.55, prev_loss=1.85]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.10batch/s]
# Training epochs on cpu:  41%|████████▌            | 82/200 [00:27<00:42,  2.78epoch/s, loss=1.68, prev_loss=1.55]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.63batch/s]
# Training epochs on cpu:  42%|████████▋            | 83/200 [00:28<00:40,  2.92epoch/s, loss=1.72, prev_loss=1.68]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.12batch/s]
# Training epochs on cpu:  42%|████████▊            | 84/200 [00:28<00:40,  2.90epoch/s, loss=1.65, prev_loss=1.72]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 66.86batch/s]
# Training epochs on cpu:  42%|████████▉            | 85/200 [00:28<00:39,  2.90epoch/s, loss=1.46, prev_loss=1.65]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 77.93batch/s]
# Training epochs on cpu:  43%|█████████            | 86/200 [00:29<00:38,  2.99epoch/s, loss=1.41, prev_loss=1.46]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.31batch/s]
# Training epochs on cpu:  44%|█████████▏           | 87/200 [00:29<00:38,  2.93epoch/s, loss=1.62, prev_loss=1.41]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 75.00batch/s]
# Training epochs on cpu:  44%|█████████▏           | 88/200 [00:29<00:36,  3.05epoch/s, loss=1.53, prev_loss=1.62]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 66.70batch/s]
# Training epochs on cpu:  44%|█████████▎           | 89/200 [00:30<00:37,  2.97epoch/s, loss=1.47, prev_loss=1.53]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 74.01batch/s]
# Training epochs on cpu:  45%|█████████▍           | 90/200 [00:30<00:35,  3.07epoch/s, loss=1.47, prev_loss=1.47]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.25batch/s]
# Training epochs on cpu:  46%|█████████▌           | 91/200 [00:30<00:35,  3.06epoch/s, loss=1.67, prev_loss=1.47]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.01batch/s]
# Training epochs on cpu:  46%|█████████▋           | 92/200 [00:31<00:36,  2.96epoch/s, loss=1.33, prev_loss=1.67]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.24batch/s]
# Training epochs on cpu:  46%|█████████▊           | 93/200 [00:31<00:37,  2.89epoch/s, loss=1.34, prev_loss=1.33]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.56batch/s]
# Training epochs on cpu:  47%|█████████▊           | 94/200 [00:31<00:37,  2.82epoch/s, loss=1.18, prev_loss=1.34]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.46batch/s]
# Training epochs on cpu:  48%|█████████▉           | 95/200 [00:32<00:37,  2.80epoch/s, loss=1.09, prev_loss=1.18]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.86batch/s]
# Training epochs on cpu:  48%|██████████           | 96/200 [00:32<00:37,  2.77epoch/s, loss=1.14, prev_loss=1.09]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.47batch/s]
# Training epochs on cpu:  48%|██████████▋           | 97/200 [00:33<00:35,  2.86epoch/s, loss=1.3, prev_loss=1.14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.27batch/s]
# Training epochs on cpu:  49%|██████████▎          | 98/200 [00:33<00:36,  2.80epoch/s, loss=0.958, prev_loss=1.3]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.10batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.59batch/s]
# Training epochs on cpu:  50%|█████████▉          | 99/200 [00:33<00:36,  2.78epoch/s, loss=1.17, prev_loss=0.958]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.70batch/s]
# Training epochs on cpu:  50%|██████████          | 100/200 [00:34<00:36,  2.73epoch/s, loss=1.13, prev_loss=1.17]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.45batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.80batch/s]
# Training epochs on cpu:  50%|██████████          | 101/200 [00:34<00:37,  2.67epoch/s, loss=1.18, prev_loss=1.13]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.85batch/s]
# Training epochs on cpu:  51%|██████████▏         | 102/200 [00:34<00:36,  2.67epoch/s, loss=1.09, prev_loss=1.18]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.62batch/s]
# Training epochs on cpu:  52%|██████████▎         | 103/200 [00:35<00:36,  2.68epoch/s, loss=1.04, prev_loss=1.09]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 57.76batch/s]
# Training epochs on cpu:  52%|█████████▉         | 104/200 [00:35<00:36,  2.65epoch/s, loss=0.987, prev_loss=1.04]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 68.73batch/s]
# Training epochs on cpu:  52%|█████████▉         | 105/200 [00:36<00:35,  2.70epoch/s, loss=1.09, prev_loss=0.987]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.13batch/s]
# Training epochs on cpu:  53%|██████████         | 106/200 [00:36<00:34,  2.70epoch/s, loss=0.955, prev_loss=1.09]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.69batch/s]
# Training epochs on cpu:  54%|██████████▏        | 107/200 [00:36<00:34,  2.68epoch/s, loss=1.01, prev_loss=0.955]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.86batch/s]
# Training epochs on cpu:  54%|██████████▊         | 108/200 [00:37<00:34,  2.65epoch/s, loss=1.12, prev_loss=1.01]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.01batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 54.52batch/s]
# Training epochs on cpu:  55%|██████████▉         | 109/200 [00:37<00:35,  2.60epoch/s, loss=1.14, prev_loss=1.12]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.06batch/s]
# Training epochs on cpu:  55%|███████████▌         | 110/200 [00:37<00:34,  2.58epoch/s, loss=0.9, prev_loss=1.14]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.75batch/s]
# Training epochs on cpu:  56%|███████████▋         | 111/200 [00:38<00:33,  2.67epoch/s, loss=1.11, prev_loss=0.9]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.35batch/s]
# Training epochs on cpu:  56%|██████████▋        | 112/200 [00:38<00:32,  2.73epoch/s, loss=0.971, prev_loss=1.11]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.23batch/s]
# Training epochs on cpu:  56%|██████████▏       | 113/200 [00:38<00:31,  2.77epoch/s, loss=0.922, prev_loss=0.971]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.31batch/s]
# Training epochs on cpu:  57%|██████████▎       | 114/200 [00:39<00:30,  2.86epoch/s, loss=0.926, prev_loss=0.922]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 64.44batch/s]
# Training epochs on cpu:  57%|██████████▎       | 115/200 [00:39<00:29,  2.84epoch/s, loss=0.965, prev_loss=0.926]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.68batch/s]
# Training epochs on cpu:  58%|██████████▍       | 116/200 [00:40<00:29,  2.83epoch/s, loss=0.999, prev_loss=0.965]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.91batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 58.63batch/s]
# Training epochs on cpu:  58%|██████████▌       | 117/200 [00:40<00:29,  2.77epoch/s, loss=0.824, prev_loss=0.999]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.99batch/s]
# Training epochs on cpu:  59%|███████████▏       | 118/200 [00:40<00:29,  2.78epoch/s, loss=0.71, prev_loss=0.824]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.93batch/s]
# Training epochs on cpu:  60%|███████████▎       | 119/200 [00:41<00:29,  2.75epoch/s, loss=0.921, prev_loss=0.71]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.81batch/s]
# Training epochs on cpu:  60%|██████████▊       | 120/200 [00:41<00:29,  2.74epoch/s, loss=0.733, prev_loss=0.921]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.82batch/s]
# Training epochs on cpu:  60%|██████████▉       | 121/200 [00:41<00:28,  2.79epoch/s, loss=0.815, prev_loss=0.733]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.26batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.89batch/s]
# Training epochs on cpu:  61%|██████████▉       | 122/200 [00:42<00:28,  2.73epoch/s, loss=0.793, prev_loss=0.815]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.93batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.74batch/s]
# Training epochs on cpu:  62%|███████████▋       | 123/200 [00:42<00:28,  2.69epoch/s, loss=0.65, prev_loss=0.793]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.06batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.69batch/s]
# Training epochs on cpu:  62%|███████████▊       | 124/200 [00:42<00:28,  2.65epoch/s, loss=0.761, prev_loss=0.65]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.39batch/s]
# Training epochs on cpu:  62%|███████████▎      | 125/200 [00:43<00:28,  2.65epoch/s, loss=0.805, prev_loss=0.761]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.63batch/s]
# Training epochs on cpu:  63%|███████████▎      | 126/200 [00:43<00:27,  2.66epoch/s, loss=0.707, prev_loss=0.805]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.41batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 59.75batch/s]
# Training epochs on cpu:  64%|███████████▍      | 127/200 [00:44<00:27,  2.65epoch/s, loss=0.718, prev_loss=0.707]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.51batch/s]
# Training epochs on cpu:  64%|███████████▌      | 128/200 [00:44<00:26,  2.73epoch/s, loss=0.721, prev_loss=0.718]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.26batch/s]
# Training epochs on cpu:  64%|███████████▌      | 129/200 [00:44<00:25,  2.74epoch/s, loss=0.684, prev_loss=0.721]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 76.17batch/s]
# Training epochs on cpu:  65%|███████████▋      | 130/200 [00:45<00:24,  2.82epoch/s, loss=0.599, prev_loss=0.684]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.30batch/s]
# Training epochs on cpu:  66%|███████████▊      | 131/200 [00:45<00:24,  2.83epoch/s, loss=0.665, prev_loss=0.599]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.65batch/s]
# Training epochs on cpu:  66%|███████████▉      | 132/200 [00:45<00:24,  2.82epoch/s, loss=0.842, prev_loss=0.665]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.66batch/s]
# Training epochs on cpu:  66%|███████████▉      | 133/200 [00:46<00:23,  2.81epoch/s, loss=0.518, prev_loss=0.842]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# ...
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 69.06batch/s]
# Training epochs on cpu:  82%|██████████████▋   | 163/200 [00:56<00:12,  2.97epoch/s, loss=0.448, prev_loss=0.344]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 72.50batch/s]
# Training epochs on cpu:  82%|██████████████▊   | 164/200 [00:57<00:12,  2.98epoch/s, loss=0.454, prev_loss=0.448]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.86batch/s]
# Training epochs on cpu:  82%|██████████████▊   | 165/200 [00:57<00:11,  2.98epoch/s, loss=0.283, prev_loss=0.454]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.30batch/s]
# Training epochs on cpu:  83%|██████████████▉   | 166/200 [00:57<00:11,  2.88epoch/s, loss=0.422, prev_loss=0.283]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 59.85batch/s]
# Training epochs on cpu:  84%|███████████████   | 167/200 [00:58<00:11,  2.86epoch/s, loss=0.377, prev_loss=0.422]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.29batch/s]
# Training epochs on cpu:  84%|███████████████   | 168/200 [00:58<00:11,  2.86epoch/s, loss=0.395, prev_loss=0.377]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.23batch/s]
# Training epochs on cpu:  84%|███████████████▏  | 169/200 [00:58<00:11,  2.80epoch/s, loss=0.448, prev_loss=0.395]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 62.37batch/s]
# Training epochs on cpu:  85%|████████████████▏  | 170/200 [00:59<00:10,  2.76epoch/s, loss=0.44, prev_loss=0.448]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.01batch/s]
# Training epochs on cpu:  86%|█████████████████   | 171/200 [00:59<00:10,  2.72epoch/s, loss=0.38, prev_loss=0.44]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.22batch/s]
# Training epochs on cpu:  86%|████████████████▎  | 172/200 [00:59<00:10,  2.75epoch/s, loss=0.449, prev_loss=0.38]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.27batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.19batch/s]
# Training epochs on cpu:  86%|███████████████▌  | 173/200 [01:00<00:09,  2.76epoch/s, loss=0.333, prev_loss=0.449]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 65.26batch/s]
# Training epochs on cpu:  87%|███████████████▋  | 174/200 [01:00<00:09,  2.75epoch/s, loss=0.419, prev_loss=0.333]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 55.74batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 48.32batch/s]
# Training epochs on cpu:  88%|███████████████▊  | 175/200 [01:01<00:09,  2.59epoch/s, loss=0.358, prev_loss=0.419]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.49batch/s]
# Training epochs on cpu:  88%|███████████████▊  | 176/200 [01:01<00:09,  2.63epoch/s, loss=0.395, prev_loss=0.358]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 61.22batch/s]
# Training epochs on cpu:  88%|███████████████▉  | 177/200 [01:01<00:08,  2.64epoch/s, loss=0.423, prev_loss=0.395]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 59.20batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 57.56batch/s]
# Training epochs on cpu:  89%|████████████████▉  | 178/200 [01:02<00:08,  2.63epoch/s, loss=0.41, prev_loss=0.423]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 48.27batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 49.14batch/s]
# Training epochs on cpu:  90%|█████████████████  | 179/200 [01:02<00:08,  2.50epoch/s, loss=0.321, prev_loss=0.41]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 51.94batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 49.10batch/s]
# Training epochs on cpu:  90%|████████████████▏ | 180/200 [01:03<00:08,  2.40epoch/s, loss=0.276, prev_loss=0.321]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 49.90batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 52.62batch/s]
# Training epochs on cpu:  90%|████████████████▎ | 181/200 [01:03<00:07,  2.42epoch/s, loss=0.391, prev_loss=0.276]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 57.37batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 56.04batch/s]
# Training epochs on cpu:  91%|████████████████▍ | 182/200 [01:03<00:07,  2.50epoch/s, loss=0.301, prev_loss=0.391]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 63.78batch/s]
# Training epochs on cpu:  92%|████████████████▍ | 183/200 [01:04<00:06,  2.57epoch/s, loss=0.304, prev_loss=0.301]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.40batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 50.94batch/s]
# Training epochs on cpu:  92%|████████████████▌ | 184/200 [01:04<00:06,  2.50epoch/s, loss=0.345, prev_loss=0.304]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 50.73batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.61batch/s]
# Training epochs on cpu:  92%|████████████████▋ | 185/200 [01:05<00:06,  2.45epoch/s, loss=0.373, prev_loss=0.345]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 56.57batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.78batch/s]
# Training epochs on cpu:  93%|████████████████▋ | 186/200 [01:05<00:05,  2.49epoch/s, loss=0.338, prev_loss=0.373]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.94batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 49.97batch/s]
# Training epochs on cpu:  94%|████████████████▊ | 187/200 [01:05<00:05,  2.42epoch/s, loss=0.288, prev_loss=0.338]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 46.70batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 43.69batch/s]
# Training epochs on cpu:  94%|████████████████▉ | 188/200 [01:06<00:05,  2.32epoch/s, loss=0.358, prev_loss=0.288]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  25%|████████████▎                                    | 3/12 [00:00<00:00, 25.71batch/s]
# Training batches on cpu:  67%|████████████████████████████████▋                | 8/12 [00:00<00:00, 34.52batch/s]
# Training epochs on cpu:  94%|█████████████████▉ | 189/200 [01:06<00:04,  2.21epoch/s, loss=0.32, prev_loss=0.358]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 53.26batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.51batch/s]
# Training epochs on cpu:  95%|██████████████████ | 190/200 [01:07<00:04,  2.23epoch/s, loss=0.324, prev_loss=0.32]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 40.06batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 46.45batch/s]
# Training epochs on cpu:  96%|█████████████████▏| 191/200 [01:07<00:04,  2.18epoch/s, loss=0.265, prev_loss=0.324]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 47.03batch/s]
# Training batches on cpu:  92%|████████████████████████████████████████████    | 11/12 [00:00<00:00, 49.32batch/s]
# Training epochs on cpu:  96%|█████████████████▎| 192/200 [01:08<00:03,  2.20epoch/s, loss=0.286, prev_loss=0.265]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 51.57batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.25batch/s]
# Training epochs on cpu:  96%|█████████████████▎| 193/200 [01:08<00:03,  2.23epoch/s, loss=0.245, prev_loss=0.286]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  33%|████████████████▎                                | 4/12 [00:00<00:00, 38.51batch/s]
# Training batches on cpu:  75%|████████████████████████████████████▊            | 9/12 [00:00<00:00, 43.02batch/s]
# Training epochs on cpu:  97%|█████████████████▍| 194/200 [01:09<00:02,  2.21epoch/s, loss=0.223, prev_loss=0.245]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 52.38batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 51.12batch/s]
# Training epochs on cpu:  98%|█████████████████▌| 195/200 [01:09<00:02,  2.26epoch/s, loss=0.342, prev_loss=0.223]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.70batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 53.33batch/s]
# Training epochs on cpu:  98%|█████████████████▋| 196/200 [01:10<00:01,  2.31epoch/s, loss=0.199, prev_loss=0.342]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  42%|████████████████████▍                            | 5/12 [00:00<00:00, 48.84batch/s]
# Training batches on cpu:  83%|████████████████████████████████████████        | 10/12 [00:00<00:00, 49.46batch/s]
# Training epochs on cpu:  98%|█████████████████▋| 197/200 [01:10<00:01,  2.28epoch/s, loss=0.286, prev_loss=0.199]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 58.47batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 59.27batch/s]
# Training epochs on cpu:  99%|█████████████████▊| 198/200 [01:10<00:00,  2.38epoch/s, loss=0.235, prev_loss=0.286]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  58%|████████████████████████████▌                    | 7/12 [00:00<00:00, 60.20batch/s]
# Training epochs on cpu: 100%|█████████████████▉| 199/200 [01:11<00:00,  2.42epoch/s, loss=0.237, prev_loss=0.235]
# Training batches on cpu:   0%|                                                         | 0/12 [00:00<?, ?batch/s]
# Training batches on cpu:  50%|████████████████████████▌                        | 6/12 [00:00<00:00, 54.33batch/s]
# Training batches on cpu: 100%|████████████████████████████████████████████████| 12/12 [00:00<00:00, 55.96batch/s]
# Training epochs on cpu: 100%|██████████████████| 200/200 [01:11<00:00,  2.79epoch/s, loss=0.275, prev_loss=0.237]
# INFO:pykeen.evaluation.evaluator:Currently automatic memory optimization only supports GPUs, but you're using a CPU. Therefore, the batch_size will be set to the default value.
# INFO:pykeen.evaluation.evaluator:No evaluation batch_size provided. Setting batch_size to '32'.
# Evaluating on cpu: 100%|█████████████████████████████████████████████████████| 159/159 [00:00<00:00, 919triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 0.19s seconds

# %% [markdown]
# ### Exercise 7 Your Own Data now
#
# Choose a dataset of your own. Best if it is the data you are using in your group project.
#
# - Create a training and testset.
# - Train your model to compute Knowledge Graph Embeddings, and save the best parameters model. - Predict new links over your dataset
# - Visualise the embeddings you computed
# - Optional : cluster your embeddings, [see this tutorial](https://docs.ampligraph.org/en/1.4.0/tutorials/ClusteringAndClassificationWithEmbeddings.html)
