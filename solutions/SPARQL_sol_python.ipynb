# %% [markdown]
# ## SPARQL exercises
#
# Below two exercises that let you explore querying with SPARQL.
#
# In SPARQL, you have four query types:
# 1. SELECT: Return matches as a collection of solution bindings.
# 2. CONSTRUCT: Create RDF triples from matches.
# 3. DESCRIBE: Create RDF triples about a resource.
# 4. ASK: Check if at least one match exists.

# %% [markdown]
# ## SPARQL exercises
#
# Below two exercises that let you explore querying with SPARQL.
#
# In SPARQL, you have four query types:
# 1. SELECT: Return matches as a collection of solution bindings.
# 2. CONSTRUCT: Create RDF triples from matches.
# 3. DESCRIBE: Create RDF triples about a resource.
# 4. ASK: Check if at least one match exists.

# %% [markdown]
# **Exercise 1**
#
# 1. Load the recipe.rdf and ingredient.rdf into GraphDB and start the SPARQL service (or you will not be able to query it)
#     - tip: load both in a separate named graph, one named graph for ingredients, and one for recipes.
# 2. Perform the following queries:
#     - SELECT all recipes and their descriptions, ordered alphabetically
#     - SELECT all recipes meant for dinner
#     - SELECT the recipes that contain the most number of ingredients
#     - ASK if there is any recipe that has a glycemic index of exactly 5.
#     - SELECT recipes that have less than 30 minutes cooking time
#
# **Construct queries:** Since a CONSTRUCT query (example below) constructs a graph, and therefor outputs triples instead of a table, you can use it to generate a modified version of the graph, but also to visualise a subgraph. In GraphDB, after running a CONSTRUCT query in the GraphDB SPARQL service, you can select 'Visual' in the lower right corner.
#
#    - try to visualise an interesting part of the graph: for example a single gluten-free recipe and its ingredients
# In the WHERE part of the query, all subjects ?s and objects ?o will be retrieved that are connected with the property wtm:hasIngredient. The CONSTRUCT part will take ?s and ?o and create a new graph, by again connecting ?s and ?o with wtm:hasIngredient. If you want to create a graph with a _new_ property, you can also do this by replacing the property in the CONSTRUCT part with another one.
#
#
# CONSTRUCT { ?s wtm:hasIngredient ?o }
# WHERE { ?s wtm:hasIngredient ?o }

# %%
from ast import arg
from rdflib import Graph, RDFS, RDF, URIRef, Namespace, Literal, XSD
from owlrl import DeductiveClosure, RDFS_Semantics
import random, sys
import sys
import os
import pandas as pd
from string import Template
import re
import json

# %%
def Query1(graph):
    res = graph.query("""
select ?label where { 
	# ?s rdf:type wtm:Ingredient .
    # ?s rdfs:label ?label 
    } order by asc(?label)
    """, initNs={'wtm': 'http://purl.org/heals/food/', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#'})

    return list(res)





def Query2(graph):
    res = graph.query("""
select * where { 
    # ?s wtm:isRecommendedForMeal wtm:Dinner, wtm:Lunch
} 
    """, initNs={'wtm': 'http://purl.org/heals/food/', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#'})

    return list(res)


def Query3(graph):
    res = graph.query("""
select ?s  (count(?o) AS ?count)
where { 
    # ?s wtm:hasIngredient ?o .
} group by (?s)
having (?count > 9)
    """, initNs={'wtm': 'http://purl.org/heals/food/', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#'})

    return list(res)



def Query4(graph):
    res = graph.query("""
ASK {
    SELECT ?s (SUM(xsd:double(?g)) as ?sum)  WHERE { 
        # ?s wtm:hasIngredient ?i . 
        # ?i  wtm:hasGlycemicIndex ?g .  
	} group by ?s
	having (?sum > xsd:double("300")) 
}

    """, initNs={'wtm': 'http://purl.org/heals/food/', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#', 'xsd': 'http://www.w3.org/2001/XMLSchema#'})

    return list(res)



def Query5(graph):
    res = graph.query("""
select * where { 
	# ?s wtm:hasCookTime ?o .
    FILTER(?o < 30)
}
    """, initNs={'wtm': 'http://purl.org/heals/food/', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#'})

    return list(res)



def Query6(graph):
    res = graph.query("""
CONSTRUCT 
	{ ?r wtm:hasIngredient ?i } 
WHERE {
    
    # ?r wtm:hasIngredient ?i . 
    
    {
        SELECT ?r {
        # ?r wtm:hasIngredient ?i . 
        MINUS { ?r wtm:hasIngredient/wtm:hasGluten True }   
        } LIMIT 1
    } 
} 

    """, initNs={'wtm': 'http://purl.org/heals/food/', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#'})

    return list(res)

# %%
g = Graph()
g.parse("../data/ingredients.rdf")
g.parse("../data/recipes.rdf")




Query5(g)
# Out:
# [(rdflib.term.URIRef('http://purl.org/heals/ingredient/ChickenSalad'),
#   rdflib.term.Literal('15', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://purl.org/heals/ingredient/ThaiChicken'),
#   rdflib.term.Literal('15', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer'))),
#  (rdflib.term.URIRef('http://purl.org/heals/ingredient/WholeGrainBananaPancake'),
#   rdflib.term.Literal('20', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#integer')))]

# %% [markdown]
# **Exercise 2**
# 1. Explore the [LMDB](https://triplydb.com/Triply/linkedmdb) dataset
# 2. Perform the following queries:
#     - How many classes are there?
#     - Which are the distinguishing properties of a <https://triplydb.com/Triply/linkedmdb/vocab/Film> class?
#     - Can you find the 5 actors that performed in most movies, and the name of these movies ?
#     - What is the IRI of “Tom Hanks (Actor)” ?
#     - Can you find the IRI of movies and with their DBpedia correspondent IRI?

# %%
def Query(graph):
    res = graph.query("""
SELECT
  DISTINCT ?s ?p ?o
WHERE
  { 
    SERVICE <http://linkeddata.uriburner.com/sparql> 
      {
        SELECT ?s ?p ?o
        WHERE {?s ?o ?o}
        LIMIT 100                
      }
  }
    """, initNs={'wtm': 'http://purl.org/heals/food/', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#'})

    return list(res)


d = Graph()
d.parse('http://linkeddata.uriburner.com/sparql')  

Query(d)
# Out:
# [(rdflib.term.URIRef('http://www.openlinksw.com/schemas/graphql/intro#__Type'),
#   None,
#   rdflib.term.URIRef('http://www.openlinksw.com/schemas/graphql/intro#fields')),
#  (rdflib.term.URIRef('urn:records:test#'),
#   None,
#   rdflib.term.URIRef('urn:records:test#')),
#  (rdflib.term.URIRef('https://sklep.sizeer.com/air-jordan-1-mid-meskie-sneakersy-bialy-554724-092'),
#   None,
#   rdflib.term.URIRef('https://sklep.sizeer.com/nowosci/kategoria-akcesoria')),
#  (rdflib.term.URIRef('https://sklep.sizeer.com/air-jordan-1-mid-meskie-sneakersy-bialy-554724-092'),
#   None,
#   rdflib.term.URIRef('https://sklep.sizeer.com/nowosci/kategoria-buty')),
#  (rdflib.term.URIRef('https://sklep.sizeer.com/air-jordan-1-mid-meskie-sneakersy-bialy-554724-092'),
#   None,
#   rdflib.term.URIRef('https://sklep.sizeer.com/nowosci/kategoria-odziez')),
#  (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P1647'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf')),
#  (rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P2235'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#subPropertyOf')),
#  (rdflib.term.URIRef('http://swlab.ddns.net:8080/void.ttl#id-1f3ab19d-8e7f-426c-b897-9de7a0b072c0'),
#   None,
#   rdflib.term.URIRef('http://rdfs.org/ns/void#property')),
#  (rdflib.term.URIRef('http://swlab.ddns.net:8080/void.ttl#id-6f174ed9-8646-4943-b14f-d72a2d651806'),
#   None,
#   rdflib.term.URIRef('http://rdfs.org/ns/void#property')),
#  (rdflib.term.URIRef('https://sparql.uniprot.org/.well-known/void#void!property'),
#   None,
#   rdflib.term.URIRef('http://rdfs.org/ns/void#property')),
#  (rdflib.term.URIRef('https://kingsley.idehen.net/public_home/jordan/Public/record-test.ttl#'),
#   None,
#   rdflib.term.URIRef('https://kingsley.idehen.net/public_home/jordan/Public/record-test.ttl#')),
#  (rdflib.term.URIRef('urn:recordjiiis:test#hi'),
#   None,
#   rdflib.term.URIRef('urn:recordjiiis:test#ji')),
#  (rdflib.term.URIRef('https://cloudflare-ipfs.com/ipfs/QmadV4bC6H1RvJ2mXS3CRwJF4MNKgcrD4nFpCveiZd6jBu#V'),
#   None,
#   rdflib.term.URIRef('https://cloudflare-ipfs.com/ipfs/QmadV4bC6H1RvJ2mXS3CRwJF4MNKgcrD4nFpCveiZd6jBu#_')),
#  (rdflib.term.URIRef('https://cloudflare-ipfs.com/ipfs/QmadV4bC6H1RvJ2mXS3CRwJF4MNKgcrD4nFpCveiZd6jBu#V'),
#   None,
#   rdflib.term.URIRef('https://cloudflare-ipfs.com/ipfs/QmadV4bC6H1RvJ2mXS3CRwJF4MNKgcrD4nFpCveiZd6jBu#q')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/workInfoHomepage'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/thumbnail'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/spec/'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Project'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/rdf-editor/data/foaf.ttl'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/schoolHomepage'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/OnlineGamingAccount'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/age'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/dnaChecksum'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/msnChatID'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('https://osde.demo.openlinksw.com/data/foaf.ttl'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Agent'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/isPrimaryTopicOf'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/primaryTopic'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/weblog'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://ods-qa.openlinksw.com/rdf-editor/data/foaf.ttl'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/workplaceHomepage'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/name'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/nick'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/logo'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/accountName'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/depiction'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/focus'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/img'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Image'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/givenName'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/account'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/publications'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/accountServiceHomepage'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/page'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Document'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/knows'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://xmlns.com/foaf/0.1/%20-%2013/'),
#   None,
#   rdflib.term.URIRef('http://xmlns.com/foaf/0.1/topic')),
#  (rdflib.term.URIRef('http://schema.org/url'),
#   None,
#   rdflib.term.URIRef('http://schema.org/url')),
#  (rdflib.term.BNode('nodeID://b36043'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36047'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36051'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36055'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36059'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36061'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36065'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36069'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36071'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36076'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36084'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.BNode('nodeID://b36088'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/ns/ui#property')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/about/id/entity/http/gmpg.org/xfn/11'),
#   None,
#   rdflib.term.URIRef('http://gmpg.org/xfn/11#copyright')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/3061434113bdb7690b193d4145f1b2e2f9bbf533'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/47b2d8ba78d15399c4e5769da05fdaf0301fd801'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/0acc5884ea80aefaaeb4f5f25ce2f3e904ec01ce'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/daa6b0815832a679967a9c26c0e8ebac413b4a9c'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/f50fdb0f81996ac1bb62c32eb65bbbddf604fcf2'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/7b0e0cbc75a4c495ebafc7342f1f789b1e957c74'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/e88f38c73123d677d2e2b2fa129a4d969d4682f0'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/457da93bc9021d9107b78ca7b194e2ee705f4aca'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/fa562247275a2dd79fa4524baeba85a1c5b0aaeb'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/01119655ecdc0eb4705af4dbc077be9c81a445af'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/10db4249d12deb84d679786eeeca392a1ccd2b19'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/79f03f3629bd53dd3913fb83d877c8e831522ef0'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/87573a8960c0c6e00a7e8062285a194f1cb1a53f'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/896b3a7550bb43313f7e2ec3b87650ebcbcef645'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/98b6170c37dcb10a265484e19cf876d47fc7e407'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/a197a9955232a67519cb63d749e33892dfee3492'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/fe4ca02cf11fcb0c18ed9a510595c1ba4d4abe'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/787d5c10d75a81b6626062d33d9be113924c813b'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/d9525ac7f2712aa6c4f682c9acbd0b20551021db'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/27c40a690464bfa5cf37b6f3f1a624daf4bdcdd3'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/28872b3f31b8348908f0c37e266fd5025dce8f71'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/396dff08956c911442184942e92c6bf1b31207b8'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/461c88bdd655f9818ff1ac064d6ea94db7678f64'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/65c0b460d296ca9e8d7f868bbc186aa6b5dd560f'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/ac2ac319243e9822159c8bf2d924f8a8c012cf10'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/fe1a1bffb2641b922f24987f3c4519ca45234eb3'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/2a2ef271963502aa31106fdbf512e9d302bb306d'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('https://linkeddata.uriburner.com/proxy-iri/e0688c985121bafccfa3b5b8d36da29e1cb7b176'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/233a03d71ec2afbeb6e323f6cbf188fbf4545539'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/439a81e2f4008465cc45fb0bc4b87f184e6b309b'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/70ca2fe1be68ef208ab45890a0b571c0b4a114a3'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/9c03f872ce2450f92a6efcc25ae8ab48c727b77f'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/0177fe9e7f3d43fc54a89fd3622caace1e93ef4d'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/0186babf15a4b88d745915fac0de0cde8443a462'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/05fe8fd146cbaa1a3fd16fbe577d34a5448b37c7'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate')),
#  (rdflib.term.URIRef('http://linkeddata.uriburner.com/proxy-iri/0ed3b41500b95978f64b266f96a23ac544b588d1'),
#   None,
#   rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate'))]

# %%
def Query(graph):
    res = graph.query("""
SELECT
  DISTINCT ?s ?p ?o
WHERE
  { 
    SERVICE <https://api.triplydb.com/datasets/Triply/linkedmdb/services/linkedmdb/sparql> 
      {
        SELECT *
        WHERE {?s ?o ?o}
        LIMIT 10               
      }
  }
    """, initNs={'wtm': 'http://purl.org/heals/food/', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#'})

    return list(res)


d = Graph()
d.parse('https://api.triplydb.com/datasets/Triply/linkedmdb')  

Query(d)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[73], line 20
#      16     return list(res)
#      19 d = Graph()
# ---> 20 d.parse('https://api.triplydb.com/datasets/Triply/linkedmdb/services/linkedmdb/sparql')
#      22 Query(d)
#
# File /usr/local/lib/python3.10/site-packages/rdflib/graph.py:1306, in Graph.parse(self, source, publicID, format, location, file, data, **args)
#    1223 def parse(
#    1224     self,
#    1225     source: Optional[
#    (...)
#    1233     **args,
#    1234 ):
#    1235     """
#    1236     Parse an RDF source adding the resulting triples to the Graph.
#    1237
#    (...)
#    1303
#    1304     """
# -> 1306     source = create_input_source(
#    1307         source=source,
#    1308         publicID=publicID,
#    1309         location=location,
#    1310         file=file,
#    1311         data=data,
#    1312         format=format,
#    1313     )
#    1314     if format is None:
#    1315         format = source.content_type
#
# File /usr/local/lib/python3.10/site-packages/rdflib/parser.py:404, in create_input_source(source, publicID, location, file, data, format)
#     396 auto_close = False  # make sure we close all file handles we open
#     398 if location is not None:
#     399     (
#     400         absolute_location,
#     401         auto_close,
#     402         file,
#     403         input_source,
# --> 404     ) = _create_input_source_from_location(
#     405         file=file,
#     406         format=format,
#     407         input_source=input_source,
#     408         location=location,
#     409     )
#     411 if file is not None:
#     412     input_source = FileInputSource(file)
#
# File /usr/local/lib/python3.10/site-packages/rdflib/parser.py:458, in _create_input_source_from_location(file, format, input_source, location)
#     456     file = open(filename, "rb")
#     457 else:
# --> 458     input_source = URLInputSource(absolute_location, format)
#     460 auto_close = True
#     461 # publicID = publicID or absolute_location  # Further to fix
#     462 # for issue 130
#
# File /usr/local/lib/python3.10/site-packages/rdflib/parser.py:282, in URLInputSource.__init__(self, system_id, format)
#     279         else:
#     280             raise
# --> 282 response: HTTPResponse = _urlopen(req)
#     283 self.url = response.geturl()  # in case redirections took place
#     284 self.links = self.get_links(response)
#
# File /usr/local/lib/python3.10/site-packages/rdflib/parser.py:270, in URLInputSource.__init__.<locals>._urlopen(req)
#     268 def _urlopen(req: Request) -> Any:
#     269     try:
# --> 270         return urlopen(req)
#     271     except HTTPError as ex:
#     272         # 308 (Permanent Redirect) is not supported by current python version(s)
#     273         # See https://bugs.python.org/issue40321
#     274         # This custom error handling should be removed once all
#     275         # supported versions of python support 308.
#     276         if ex.code == 308:
#
# File /usr/local/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/local/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/local/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/local/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /usr/local/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/local/Cellar/python@3.10/3.10.9/Frameworks/Python.framework/Versions/3.10/lib/python3.10/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Expected 'query' argument.
